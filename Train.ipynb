# %%
import os
import math
import random
import numpy as np
import tensorflow.compat.v1 as tf
tf.compat.v1.disable_eager_execution()

# %% [markdown]
# #### 학습에 필요한 설정값을 정의

# %%
# Epsilon 값.
epsilon = 1

# Epsilon 최소값.
epsilonMinimumValue = .001

# 에이전트의 행동 개수(좌로 움직이기, 가만히 있기, 우로 움직이기)
num_actions = 3

# 학습 반복 횟수.
num_epochs = 1000

# 은닉층의 개수.
hidden_size = 128

# Replay Memory 크기.(과거 행위를 기억하기 위한 공간)
maxMemory = 500

# batch size .
batch_size = 50

# 환경 크기.(게임판 크기)
gridSize = 10

# 게임 환경의 현재 상태.(10 x10)
state_size = gridSize * gridSize

# 규제강도.
discount = 0.9

# 학습률.
learning_rage = 0.2

# %% [markdown]
# #### 시작과 끝값을 기준으로 랜덤값을 추출하는 함수를 정의

# %%
def randf(s, e) :
    return (float(random.randrange(0, (e - s) * 9999)) / 10000) + s

# %% [markdown]
# #### DQN 모델을 정의

# %%
def build_DQN(x) :
    
    # 표준화를 위한 계수.
    a1 = 1.0 / math.sqrt(float(state_size))
    W1 = tf.Variable(tf.truncated_normal(shape=[state_size, hidden_size], stddev=a1))
    b1 = tf.Variable(tf.truncated_normal(shape=[hidden_size], stddev=0.01))
    H1_output = tf.nn.relu(tf.matmul(x, W1) + b1)
    
    a2 = 1.0 / math.sqrt(float(hidden_size))
    W2 = tf.Variable(tf.truncated_normal(shape=[hidden_size, hidden_size], stddev=a2))
    b2 = tf.Variable(tf.truncated_normal(shape=[hidden_size], stddev=0.01))
    H2_output = tf.nn.relu(tf.matmul(H1_output, W2) + b2)
    
    W3 = tf.Variable(tf.truncated_normal(shape=[hidden_size, num_actions], stddev=a2))
    b3 = tf.Variable(tf.truncated_normal(shape=[num_actions], stddev=0.01))
    output_layer = tf.matmul(H2_output, W3) + b3
    
    return tf.squeeze(output_layer)

# %%
# 입력 화면 이미지와 타켓 Q값을 받기 위한 플레이스 홀더(메모리상의 저장공간)를 선언.
x = tf.placeholder(tf.float32, shape=[None, state_size])
y = tf.placeholder(tf.float32, shape=[None, num_actions])

# %%
# DQN 모델을 선언하고 예측 결과를 리턴.
y_pred = build_DQN(x)

# %%
# MSE 손실 함수와 옵티마이저를 정의.
loss      = tf.reduce_sum(tf.square(y-y_pred)) / (2 * batch_size)
optimizer = tf.train.GradientDescentOptimizer(learning_rage).minimize(loss)

# %% [markdown]
# #### 게임 환경 구현

# %%
class CatchEnvironment() :
    
    # 상태의 초기값을 지정.
    def __init__(self, gridSize) :
        
        # 그리드 개수.
        self.gridSize = gridSize
        
        # 입력 데이터 개수(그리드 개수 * 그리그 개수)
        self.state_size = self.gridSize * self.gridSize
        
        # 결과를 담을 행렬.
        self.state = np.empty(3, dtype = np.uint8)
        
        
    # 관찰 결과를 리턴.
    def observe(self) :
        # 현재 게임 화면 상태를 받아오기.
        canvas = self.drawState()
        
        # 1차원 행렬로 변환.
        canvas = np.reshape(canvas, (-1, self.state_size))
        
        return canvas
    
    # 게임 현재 상태를 계산.
    def drawState(self) :
        
        # 입력 데이터의 수 만큼의 행렬 계산.
        canvas = np.zeros((self.gridSize, self.gridSize))
        
        # 과일을 설정.
        canvas[self.state[0] - 1, self.state[1] - 1] = 1
        
        # 바구니를 설정.
        canvas[self.gridSize - 1, self.state[2] - 1 - 1] = 1
        canvas[self.gridSize - 1, self.state[2] - 1] = 1
        canvas[self.gridSize - 1, self.state[2] - 1 + 1] = 1
        
        return canvas
    
    # 게임을 초기상태로 리셋.
    def reset(self) :
        
        # 초기 과일 위치 초기화.
        initialFruitColumn    = random.randrange(1, self.gridSize + 1)
        
        # 초기 바구니 위치 초기화.
        initialBucketPosition = random.randrange(2, self.gridSize + 1 - 1)
        
        # 현재 상태 담기.
        self.state            = np.array([1, initialFruitColumn, initialBucketPosition])
        
        return self.getState()
    
    # 현재 상태를 불러오기.
    def getState(self) :
        stateInfo = self.state
        
        # 과일의 세로 위치.
        fruit_row = stateInfo[0]
        # 과일의 가로 위치.
        fruit_col = stateInfo[1]
        # 바구니의 가로 위치.
        basket = stateInfo[2]
        
        return fruit_row, fruit_col, basket
    
    
    # 에이전트가 취한 행동에 대한 보상을 줌.
    def getReward(self) :
        
        # 각 위치값의 위치를 가져오기.
        fruitRow, fruitCol, basket = self.getState()
        
        # 과일이 바닥에 닿았을 경우...
        if (fruitRow == self.gridSize - 1) :
            
            # 바구니가 과일을 받았다면 보상을 1로 반환.
            if (abs(fruitCol - basket) <= 1) :
                return 1
            
            # 과일을 받지 못했다면 보상을 -1로 반환.
            else :
                return -1
            
        # 과일이 바닥에 닿지 않았을 경우...
        else :
            # 아직 바닥에 닿지 않았으므로 보상을 0으로 반환.
            return 0
        
    # 게임이 끝났는지 확인.(1판 종료)
    def isGameOver(self) :
        # 과일이 바닥에 닿았는지 검사.
        if self.state[0] == self.gridSize - 1 :
            return True
        else :
            return False
        
        
    # action(좌, 제자리, 우)에 따라 바구니와 과일의 위치를 수정.
    def updateState(self, action) :
        move = 0
        if action == 0 :
            move = -1
        elif action == 1 :
            move = 0
        elif action == 2 :
            move = 1
            
        # 현재 과일과 바구니 위치를 가져오기.
        fruitRow, fruitCol, basket = self.getState()
        
        # 바구니의 위치를 업데이트.(min, max는 grid 밖으로 벗어나는 것을 방지)
        newBasket = min(max(2, basket + move), self.gridSize - 1)
        
        # 과일은 아래로 한칸 내리기.
        fruitRow = fruitRow + 1
        
        # 현재 상태로 다시 설정.
        self.state = np.array([fruitRow, fruitCol, newBasket])
        
    # 행동 수행.
    def act(self, action) :
        # Action 에 따라 현재 상태를 업데이트.
        self.updateState(action)
        
        # 업데이트된 상태를 보고 보상을 결정.
        reward = self.getReward()
        
        # 현재 게임 한판이 끝났는지 확인.
        gameOver = self.isGameOver()
        
        return self.observe(), reward, gameOver, self.getState()

# %%
class ReplayMemory() :
    def __init__(self, gridSize, maxMemory, discount) :
        
        # 초기값 설정.
        
        # 사용할 최대 메모리량.
        self.maxMemory  = maxMemory
        # 게임 환경의 가로 세로 칸의 수.
        self.gridSize   = gridSize
        # 가로 * 세로 칸의 수.
        self.state_size = self.gridSize * self.gridSize
        # 규제 강도.
        self.discount   = discount
        
        # 게임 데이터를 담을 행렬 생성.
        canvas = np.zeros((self.gridSize * self.gridSize))
        canvas = np.reshape(canvas, (-1, self.state_size))
        
        # 입력 데이터를 담을 행렬 생성.
        self.inputState = np.empty((self.maxMemory, 100), dtype = np.float32)
        # 에이전트의 행동 데이터를 담을 행렬.
        self.actions    = np.zeros(self.maxMemory, dtype = np.uint8)
        # 에이전트가 행동을 취한 다음의 게임 상태를 담을 행렬.
        self.nextState  = np.empty((self.maxMemory, 100), dtype = np.float32)
        # 게임 오버 여부.
        self.gameOver   = np.empty(self.maxMemory, dtype = np.bool)
        # 보상.
        self.rewards    = np.empty(self.maxMemory, dtype = np.int8)
        
        # 플레이 횟수.
        self.count   = 0
        # 현재 보상의 결과.
        self.current = 0
        
    # 경험 저장.
    def remember(self, currentState, action, reward, nextState, gameOver) :
        self.actions[self.current]         = action
        self.rewards[self.current]         = reward
        self.inputState[self.current, ...] = currentState
        self.nextState[self.current, ...]  = nextState
        self.gameOver[self.current]        = gameOver
        self.count                         = max(self.count, self.current + 1)
        self.current                       = (self.current + 1) % self.maxMemory
        
    # 입력과 학습을 준비.
    def getBatch(self, y_pred, batch_size, num_actions, state_size, sess, X) :
        # 위에서 설정한 Batch size와 최대 메모리를 비교하여 더 작은 값을 구함.
        memoryLength    = self.count
        chosenBatchSize = min(batch_size, memoryLength)

        # 입력과 결과 데이터를 담을 행렬 생성.
        inputs  = np.zeros((chosenBatchSize, state_size))
        targets = np.zeros((chosenBatchSize, num_actions))
        
         # 배치 안에서 값을 추출하여 담기.
        for i in range(chosenBatchSize) :
            # 배치에 포함될 기억을 랜덤하게 선택.
            randomIndex = random.randrange(0, memoryLength)
            
             # 현재 상태와 Q값을 가져옴.
            current_inputState = np.reshape(self.inputState[randomIndex], (1, 100))
            target             = sess.run(y_pred, feed_dict = {X : current_inputState})

            # 현재 상태 바로 다음 상태를 불러오고 다음 상태에서 취할 수 있는 가장 큰 Q값을 계산.
            current_nextState  = np.reshape(self.nextState[randomIndex], (1, 100))
            nextStateQ         = sess.run(y_pred, feed_dict = {X : current_nextState})
            nextStateMaxQ      = np.amax(nextStateQ)
            
            # 게임 오버일시 보상으로 Q값을 업데이트.
            if (self.gameOver[randomIndex] == True):
                target[self.actions[randomIndex]] = self.rewards[randomIndex]
            else:
                target[self.actions[randomIndex]] = self.rewards[randomIndex] + self.discount * nextStateMaxQ

            # 입력과 결과 데이터에 값을 저장.
            inputs[i]  = current_inputState
            targets[i] = target

        # 결과 리턴.
        return inputs, targets

# %% [markdown]
# #### Tensorflow를 통해 학습 가동시 자동으로 호출되는 함수

# %%
def main(_) :
    print('학습을 시작하겠습니다.')
    
    # 게임 플레이 환경 선언.
    env = CatchEnvironment(gridSize)
    
    # ReplayMemory 선언.
    memory = ReplayMemory(gridSize, maxMemory, discount)
    
    # 학습된 파라미터를 저장하기 위한 Saver 선언.
    saver = tf.train.Saver()
    
    # 과일을 받은 수.
    winCount = 0
    
    # With 문을 통해 작업이 완료되면 Tensorflow가 자동 종료.
    with tf.Session() as sess :
        # 변수들 초기값 할당.
        sess.run(tf.global_variables_initializer())
        
        # 학습 횟수 만큼 반복.
        for i in range(num_epochs + 1) :
            # 환경 초기화.
            err = 0
            env.reset()
            isGameOver = False
            
            # 최초 상태 가져오기.
            currentState = env.observe()
            
            # 과일이 바닥에 닿을 때까지 반복.
            while isGameOver != True :
                # Q값을 초기화.
                action = -9999
                global epsilon
                
                # 만약 0 ~ 1 사이의 임의값이 앱실론 값보다 작거나 같을 경우...
                if randf(0, 1) <= epsilon :
                    # 랜덤 행동 지정.
                    action = random.randrange(0, num_actions)
                # 클 경우...
                else :
                    # 각 행동에 대한 Q값을 계산.
                    q = sess.run(y_pred, feed_dict = {x : currentState})
                    
                    # q가 가장 큰 행동을 담기.
                    action = q.argmax()
                
                # 앱실론 값에 0.999 값을 곱해서 앱실론 값을 조정.
                if epsilon > epsilonMinimumValue :
                    epsilon = epsilon * 0.999
                
                # 에이전트가 구한 행동을 통해 보상과 다음 상태를 가져옴.
                nextState, reward, gameOver, stateInfo = env.act(action)
                
                # 만약 과일을 받아냈다고 한다면, 점수를 1 증가.
                if reward == 1:
                    winCount = winCount + 1
                    
                # 에이전트가 행동한 결과를 replayMemory에 저장.
                memory.remember(currentState, action, reward, nextState, gameOver)
                
                # 다음 이동을 위해 현재 상태를 재설정.
                currentState = nextState
                
                # 게임 오버 여부를 담기.
                isGameOver = gameOver
                
                # ReplayMemory로 부터 학습에 사용할 Batch 데이터를 가져오기.
                inputs, targets = memory.getBatch(y_pred, batch_size, num_actions, state_size, sess, x)
                
                # 최적화(가중치 수정)을 수행하고, 손실함수를 반환.
                _, loss_print = sess.run([optimizer, loss], feed_dict = {x : inputs, y : targets})
                
                # 손실율 누적.
                err += loss_print
            
            a100 = (float(winCount) / float(i + 1)) * 100
            print(f'반복 : {i}, 에러 : {err}, 승리 : {winCount}, 승리비율 : {a100}')
        
        print('학습이 완료되었습니다.')
        save_path = saver.save(sess, 'model.ckpt')
        print('모델을 저장하였습니다.')

# %%
if __name__ == '__main__' :
    # main 함수 호출.
    tf.app.run()
# Out:
# 학습을 시작하겠습니다.
# 반복 : 0, 에러 : 0.0009233761182656508, 승리 : 1, 승리비율 : 100.0
# 반복 : 1, 에러 : 0.08607495712931268, 승리 : 1, 승리비율 : 50.0
# 반복 : 2, 에러 : 0.13650890812277794, 승리 : 1, 승리비율 : 33.33333333333333
# 반복 : 3, 에러 : 0.20879818958928809, 승리 : 1, 승리비율 : 25.0
# 반복 : 4, 에러 : 0.27168971952050924, 승리 : 1, 승리비율 : 20.0
# 반복 : 5, 에러 : 0.4092440139502287, 승리 : 1, 승리비율 : 16.666666666666664
# 반복 : 6, 에러 : 0.404782485216856, 승리 : 2, 승리비율 : 28.57142857142857
# 반복 : 7, 에러 : 0.38252265378832817, 승리 : 2, 승리비율 : 25.0
# 반복 : 8, 에러 : 0.4334502089768648, 승리 : 2, 승리비율 : 22.22222222222222
# 반복 : 9, 에러 : 0.41644234023988247, 승리 : 2, 승리비율 : 20.0
# 반복 : 10, 에러 : 0.3414793200790882, 승리 : 2, 승리비율 : 18.181818181818183
# 반복 : 11, 에러 : 0.5242220982909203, 승리 : 2, 승리비율 : 16.666666666666664
# 반복 : 12, 에러 : 0.43035666085779667, 승리 : 2, 승리비율 : 15.384615384615385
# 반복 : 13, 에러 : 0.3921505808830261, 승리 : 3, 승리비율 : 21.428571428571427
# 반복 : 14, 에러 : 0.4491836465895176, 승리 : 3, 승리비율 : 20.0
# 반복 : 15, 에러 : 0.42273159325122833, 승리 : 4, 승리비율 : 25.0
# 반복 : 16, 에러 : 0.41663422249257565, 승리 : 4, 승리비율 : 23.52941176470588
# 반복 : 17, 에러 : 0.4465400353074074, 승리 : 4, 승리비율 : 22.22222222222222
# 반복 : 18, 에러 : 0.3886302784085274, 승리 : 5, 승리비율 : 26.31578947368421
# 반복 : 19, 에러 : 0.3700999766588211, 승리 : 5, 승리비율 : 25.0
# 반복 : 20, 에러 : 0.3091970905661583, 승리 : 5, 승리비율 : 23.809523809523807
# 반복 : 21, 에러 : 0.3014083467423916, 승리 : 5, 승리비율 : 22.727272727272727
# 반복 : 22, 에러 : 0.3380723427981138, 승리 : 6, 승리비율 : 26.08695652173913
# 반복 : 23, 에러 : 0.3667104970663786, 승리 : 6, 승리비율 : 25.0
# 반복 : 24, 에러 : 0.30659423023462296, 승리 : 6, 승리비율 : 24.0
# 반복 : 25, 에러 : 0.3840793455019593, 승리 : 7, 승리비율 : 26.923076923076923
# 반복 : 26, 에러 : 0.37509782426059246, 승리 : 8, 승리비율 : 29.629629629629626
# 반복 : 27, 에러 : 0.36456000059843063, 승리 : 8, 승리비율 : 28.57142857142857
# 반복 : 28, 에러 : 0.3707683440297842, 승리 : 9, 승리비율 : 31.03448275862069
# 반복 : 29, 에러 : 0.4249271024018526, 승리 : 9, 승리비율 : 30.0
# 반복 : 30, 에러 : 0.38393471017479897, 승리 : 9, 승리비율 : 29.03225806451613
# 반복 : 31, 에러 : 0.30603644624352455, 승리 : 9, 승리비율 : 28.125
# 반복 : 32, 에러 : 0.36547205597162247, 승리 : 9, 승리비율 : 27.27272727272727
# 반복 : 33, 에러 : 0.35311589017510414, 승리 : 9, 승리비율 : 26.47058823529412
# 반복 : 34, 에러 : 0.34757548570632935, 승리 : 10, 승리비율 : 28.57142857142857
# 반복 : 35, 에러 : 0.27464236319065094, 승리 : 10, 승리비율 : 27.77777777777778
# 반복 : 36, 에러 : 0.3202038072049618, 승리 : 10, 승리비율 : 27.027027027027028
# 반복 : 37, 에러 : 0.31327956914901733, 승리 : 10, 승리비율 : 26.31578947368421
# 반복 : 38, 에러 : 0.3207219112664461, 승리 : 11, 승리비율 : 28.205128205128204
# 반복 : 39, 에러 : 0.3057471811771393, 승리 : 11, 승리비율 : 27.500000000000004
# 반복 : 40, 에러 : 0.27706919983029366, 승리 : 11, 승리비율 : 26.82926829268293
# 반복 : 41, 에러 : 0.3166186735033989, 승리 : 11, 승리비율 : 26.190476190476193
# 반복 : 42, 에러 : 0.2800980182364583, 승리 : 11, 승리비율 : 25.581395348837212
# 반복 : 43, 에러 : 0.30594879016280174, 승리 : 11, 승리비율 : 25.0
# 반복 : 44, 에러 : 0.27680068649351597, 승리 : 11, 승리비율 : 24.444444444444443
# 반복 : 45, 에러 : 0.27398430556058884, 승리 : 11, 승리비율 : 23.91304347826087
# 반복 : 46, 에러 : 0.30091998260468245, 승리 : 11, 승리비율 : 23.404255319148938
# 반복 : 47, 에러 : 0.3086951421573758, 승리 : 12, 승리비율 : 25.0
# 반복 : 48, 에러 : 0.21448711212724447, 승리 : 12, 승리비율 : 24.489795918367346
# 반복 : 49, 에러 : 0.2609139736741781, 승리 : 12, 승리비율 : 24.0
# 반복 : 50, 에러 : 0.25655319541692734, 승리 : 12, 승리비율 : 23.52941176470588
# 반복 : 51, 에러 : 0.3105094823986292, 승리 : 12, 승리비율 : 23.076923076923077
# 반복 : 52, 에러 : 0.2321596834808588, 승리 : 13, 승리비율 : 24.528301886792452
# 반복 : 53, 에러 : 0.3040850209072232, 승리 : 13, 승리비율 : 24.074074074074073
# 반복 : 54, 에러 : 0.3173105791211128, 승리 : 13, 승리비율 : 23.636363636363637
# 반복 : 55, 에러 : 0.26700415555387735, 승리 : 14, 승리비율 : 25.0
# 반복 : 56, 에러 : 0.31570805236697197, 승리 : 15, 승리비율 : 26.31578947368421
# 반복 : 57, 에러 : 0.24221748113632202, 승리 : 16, 승리비율 : 27.586206896551722
# 반복 : 58, 에러 : 0.2610751762986183, 승리 : 16, 승리비율 : 27.11864406779661
# 반복 : 59, 에러 : 0.2562175467610359, 승리 : 17, 승리비율 : 28.333333333333332
# 반복 : 60, 에러 : 0.261583648622036, 승리 : 17, 승리비율 : 27.86885245901639
# 반복 : 61, 에러 : 0.19473404064774513, 승리 : 17, 승리비율 : 27.419354838709676
# 반복 : 62, 에러 : 0.28512820042669773, 승리 : 17, 승리비율 : 26.984126984126984
# 반복 : 63, 에러 : 0.24437418207526207, 승리 : 17, 승리비율 : 26.5625
# 반복 : 64, 에러 : 0.21409142296761274, 승리 : 17, 승리비율 : 26.153846153846157
# 반복 : 65, 에러 : 0.265921276062727, 승리 : 18, 승리비율 : 27.27272727272727
# 반복 : 66, 에러 : 0.26112391240894794, 승리 : 18, 승리비율 : 26.865671641791046
# 반복 : 67, 에러 : 0.2658358868211508, 승리 : 18, 승리비율 : 26.47058823529412
# 반복 : 68, 에러 : 0.24087778013199568, 승리 : 18, 승리비율 : 26.08695652173913
# 반복 : 69, 에러 : 0.2669137064367533, 승리 : 19, 승리비율 : 27.142857142857142
# 반복 : 70, 에러 : 0.24992198310792446, 승리 : 19, 승리비율 : 26.76056338028169
# 반복 : 71, 에러 : 0.2943391241133213, 승리 : 19, 승리비율 : 26.38888888888889
# 반복 : 72, 에러 : 0.2507477980107069, 승리 : 19, 승리비율 : 26.027397260273972
# 반복 : 73, 에러 : 0.2090631239116192, 승리 : 19, 승리비율 : 25.675675675675674
# 반복 : 74, 에러 : 0.28720592707395554, 승리 : 20, 승리비율 : 26.666666666666668
# 반복 : 75, 에러 : 0.1888676113449037, 승리 : 20, 승리비율 : 26.31578947368421
# 반복 : 76, 에러 : 0.1990111842751503, 승리 : 20, 승리비율 : 25.97402597402597
# 반복 : 77, 에러 : 0.3405302111059427, 승리 : 20, 승리비율 : 25.64102564102564
# 반복 : 78, 에러 : 0.20260332245379686, 승리 : 21, 승리비율 : 26.582278481012654
# 반복 : 79, 에러 : 0.1880078176036477, 승리 : 22, 승리비율 : 27.500000000000004
# 반복 : 80, 에러 : 0.2643140982836485, 승리 : 22, 승리비율 : 27.160493827160494
# 반복 : 81, 에러 : 0.28232403844594955, 승리 : 22, 승리비율 : 26.82926829268293
# 반복 : 82, 에러 : 0.2233317093923688, 승리 : 22, 승리비율 : 26.506024096385545
# 반복 : 83, 에러 : 0.24969750083982944, 승리 : 22, 승리비율 : 26.190476190476193
# 반복 : 84, 에러 : 0.27452423982322216, 승리 : 23, 승리비율 : 27.058823529411764
# 반복 : 85, 에러 : 0.22906334325671196, 승리 : 23, 승리비율 : 26.744186046511626
# 반복 : 86, 에러 : 0.2265486642718315, 승리 : 24, 승리비율 : 27.586206896551722
# 반복 : 87, 에러 : 0.2457283642143011, 승리 : 24, 승리비율 : 27.27272727272727
# 반복 : 88, 에러 : 0.23991267289966345, 승리 : 24, 승리비율 : 26.96629213483146
# 반복 : 89, 에러 : 0.24028208199888468, 승리 : 24, 승리비율 : 26.666666666666668
# 반복 : 90, 에러 : 0.1704343482851982, 승리 : 24, 승리비율 : 26.373626373626376
# 반복 : 91, 에러 : 0.27582783065736294, 승리 : 25, 승리비율 : 27.173913043478258
# 반복 : 92, 에러 : 0.29643879272043705, 승리 : 25, 승리비율 : 26.881720430107524
# 반복 : 93, 에러 : 0.20644373632967472, 승리 : 26, 승리비율 : 27.659574468085108
# 반복 : 94, 에러 : 0.20296189282089472, 승리 : 26, 승리비율 : 27.368421052631582
# 반복 : 95, 에러 : 0.24562754714861512, 승리 : 26, 승리비율 : 27.083333333333332
# 반복 : 96, 에러 : 0.23299194779247046, 승리 : 26, 승리비율 : 26.804123711340207
# 반복 : 97, 에러 : 0.19578800071030855, 승리 : 27, 승리비율 : 27.55102040816326
# 반복 : 98, 에러 : 0.32775840628892183, 승리 : 27, 승리비율 : 27.27272727272727
# 반복 : 99, 에러 : 0.20751488767564297, 승리 : 27, 승리비율 : 27.0
# 반복 : 100, 에러 : 0.20036296918988228, 승리 : 27, 승리비율 : 26.732673267326735
# 반복 : 101, 에러 : 0.2369089974090457, 승리 : 27, 승리비율 : 26.47058823529412
# 반복 : 102, 에러 : 0.2533387141302228, 승리 : 27, 승리비율 : 26.21359223300971
# 반복 : 103, 에러 : 0.28331694938242435, 승리 : 27, 승리비율 : 25.961538461538463
# 반복 : 104, 에러 : 0.1961194695904851, 승리 : 27, 승리비율 : 25.71428571428571
# 반복 : 105, 에러 : 0.2179567739367485, 승리 : 27, 승리비율 : 25.471698113207548
# 반복 : 106, 에러 : 0.16570445336401463, 승리 : 27, 승리비율 : 25.233644859813083
# 반복 : 107, 에러 : 0.24671402852982283, 승리 : 27, 승리비율 : 25.0
# 반복 : 108, 에러 : 0.23564424831420183, 승리 : 28, 승리비율 : 25.688073394495415
# 반복 : 109, 에러 : 0.25464810710400343, 승리 : 28, 승리비율 : 25.454545454545453
# 반복 : 110, 에러 : 0.24849374685436487, 승리 : 28, 승리비율 : 25.225225225225223
# 반복 : 111, 에러 : 0.22734893672168255, 승리 : 28, 승리비율 : 25.0
# 반복 : 112, 에러 : 0.24221520870923996, 승리 : 28, 승리비율 : 24.778761061946902
# 반복 : 113, 에러 : 0.2626143619418144, 승리 : 29, 승리비율 : 25.438596491228072
# 반복 : 114, 에러 : 0.20102701615542173, 승리 : 30, 승리비율 : 26.08695652173913
# 반복 : 115, 에러 : 0.1942693218588829, 승리 : 30, 승리비율 : 25.862068965517242
# 반복 : 116, 에러 : 0.17102500796318054, 승리 : 31, 승리비율 : 26.495726495726498
# 반복 : 117, 에러 : 0.25422757398337126, 승리 : 31, 승리비율 : 26.27118644067797
# 반복 : 118, 에러 : 0.2095881961286068, 승리 : 32, 승리비율 : 26.89075630252101
# 반복 : 119, 에러 : 0.2057451382279396, 승리 : 32, 승리비율 : 26.666666666666668
# 반복 : 120, 에러 : 0.14758348790928721, 승리 : 32, 승리비율 : 26.446280991735538
# 반복 : 121, 에러 : 0.26519873179495335, 승리 : 32, 승리비율 : 26.229508196721312
# 반복 : 122, 에러 : 0.2093199072405696, 승리 : 32, 승리비율 : 26.01626016260163
# 반복 : 123, 에러 : 0.12994266208261251, 승리 : 32, 승리비율 : 25.806451612903224
# 반복 : 124, 에러 : 0.15774843376129866, 승리 : 32, 승리비율 : 25.6
# 반복 : 125, 에러 : 0.16206358838826418, 승리 : 32, 승리비율 : 25.396825396825395
# 반복 : 126, 에러 : 0.18058714736253023, 승리 : 33, 승리비율 : 25.984251968503933
# 반복 : 127, 에러 : 0.26796148903667927, 승리 : 33, 승리비율 : 25.78125
# 반복 : 128, 에러 : 0.20548114459961653, 승리 : 33, 승리비율 : 25.581395348837212
# 반복 : 129, 에러 : 0.16210596729069948, 승리 : 34, 승리비율 : 26.153846153846157
# 반복 : 130, 에러 : 0.22329303435981274, 승리 : 35, 승리비율 : 26.717557251908396
# 반복 : 131, 에러 : 0.13843524549156427, 승리 : 35, 승리비율 : 26.515151515151516
# 반복 : 132, 에러 : 0.12448479514569044, 승리 : 36, 승리비율 : 27.06766917293233
# 반복 : 133, 에러 : 0.15538817830383778, 승리 : 36, 승리비율 : 26.865671641791046
# 반복 : 134, 에러 : 0.14008867926895618, 승리 : 37, 승리비율 : 27.40740740740741
# 반복 : 135, 에러 : 0.15112204663455486, 승리 : 37, 승리비율 : 27.205882352941174
# 반복 : 136, 에러 : 0.14091580640524626, 승리 : 37, 승리비율 : 27.00729927007299
# 반복 : 137, 에러 : 0.12764888117089868, 승리 : 37, 승리비율 : 26.811594202898554
# 반복 : 138, 에러 : 0.20034929737448692, 승리 : 37, 승리비율 : 26.618705035971225
# 반복 : 139, 에러 : 0.14789088536053896, 승리 : 37, 승리비율 : 26.42857142857143
# 반복 : 140, 에러 : 0.14715324342250824, 승리 : 37, 승리비율 : 26.24113475177305
# 반복 : 141, 에러 : 0.14229625463485718, 승리 : 38, 승리비율 : 26.76056338028169
# 반복 : 142, 에러 : 0.19843628350645304, 승리 : 38, 승리비율 : 26.573426573426573
# 반복 : 143, 에러 : 0.17610068526118994, 승리 : 39, 승리비율 : 27.083333333333332
# 반복 : 144, 에러 : 0.16160066612064838, 승리 : 39, 승리비율 : 26.89655172413793
# 반복 : 145, 에러 : 0.0910564586520195, 승리 : 39, 승리비율 : 26.71232876712329
# 반복 : 146, 에러 : 0.1429955903440714, 승리 : 40, 승리비율 : 27.2108843537415
# 반복 : 147, 에러 : 0.1628803163766861, 승리 : 40, 승리비율 : 27.027027027027028
# 반복 : 148, 에러 : 0.1398266302421689, 승리 : 40, 승리비율 : 26.845637583892618
# 반복 : 149, 에러 : 0.15614586975425482, 승리 : 40, 승리비율 : 26.666666666666668
# 반복 : 150, 에러 : 0.14968072157353163, 승리 : 41, 승리비율 : 27.1523178807947
# 반복 : 151, 에러 : 0.14046343136578798, 승리 : 42, 승리비율 : 27.631578947368425
# 반복 : 152, 에러 : 0.18710466008633375, 승리 : 42, 승리비율 : 27.450980392156865
# 반복 : 153, 에러 : 0.1291245175525546, 승리 : 43, 승리비율 : 27.92207792207792
# 반복 : 154, 에러 : 0.11347471829503775, 승리 : 43, 승리비율 : 27.741935483870968
# 반복 : 155, 에러 : 0.1162619274109602, 승리 : 44, 승리비율 : 28.205128205128204
# 반복 : 156, 에러 : 0.12260603625327349, 승리 : 45, 승리비율 : 28.662420382165603
# 반복 : 157, 에러 : 0.11774092633277178, 승리 : 45, 승리비율 : 28.48101265822785
# 반복 : 158, 에러 : 0.11809586174786091, 승리 : 46, 승리비율 : 28.930817610062892
# 반복 : 159, 에러 : 0.12448048684746027, 승리 : 47, 승리비율 : 29.375
# 반복 : 160, 에러 : 0.12560611916705966, 승리 : 48, 승리비율 : 29.81366459627329
# 반복 : 161, 에러 : 0.14510808791965246, 승리 : 48, 승리비율 : 29.629629629629626
# 반복 : 162, 에러 : 0.11911144759505987, 승리 : 49, 승리비율 : 30.061349693251532
# 반복 : 163, 에러 : 0.153703510761261, 승리 : 49, 승리비율 : 29.878048780487802
# 반복 : 164, 에러 : 0.1304088095203042, 승리 : 49, 승리비율 : 29.6969696969697
# 반복 : 165, 에러 : 0.11188060510903597, 승리 : 50, 승리비율 : 30.120481927710845
# 반복 : 166, 에러 : 0.10219277255237103, 승리 : 50, 승리비율 : 29.94011976047904
# 반복 : 167, 에러 : 0.15741786267608404, 승리 : 50, 승리비율 : 29.761904761904763
# 반복 : 168, 에러 : 0.13573263632133603, 승리 : 51, 승리비율 : 30.17751479289941
# 반복 : 169, 에러 : 0.12588290497660637, 승리 : 52, 승리비율 : 30.58823529411765
# 반복 : 170, 에러 : 0.14215946104377508, 승리 : 52, 승리비율 : 30.409356725146196
# 반복 : 171, 에러 : 0.09576136339455843, 승리 : 52, 승리비율 : 30.23255813953488
# 반복 : 172, 에러 : 0.11311844130977988, 승리 : 53, 승리비율 : 30.63583815028902
# 반복 : 173, 에러 : 0.1280910074710846, 승리 : 53, 승리비율 : 30.45977011494253
# 반복 : 174, 에러 : 0.1606703270226717, 승리 : 53, 승리비율 : 30.28571428571429
# 반복 : 175, 에러 : 0.1281627146527171, 승리 : 53, 승리비율 : 30.113636363636363
# 반복 : 176, 에러 : 0.12002652697265148, 승리 : 53, 승리비율 : 29.943502824858758
# 반복 : 177, 에러 : 0.1282457197085023, 승리 : 53, 승리비율 : 29.775280898876407
# 반복 : 178, 에러 : 0.12552884221076965, 승리 : 53, 승리비율 : 29.608938547486037
# 반복 : 179, 에러 : 0.10684697702527046, 승리 : 54, 승리비율 : 30.0
# 반복 : 180, 에러 : 0.15130665618926287, 승리 : 55, 승리비율 : 30.386740331491712
# 반복 : 181, 에러 : 0.10813418822363019, 승리 : 55, 승리비율 : 30.21978021978022
# 반복 : 182, 에러 : 0.14624955039471388, 승리 : 56, 승리비율 : 30.601092896174865
# 반복 : 183, 에러 : 0.1563143953680992, 승리 : 57, 승리비율 : 30.978260869565215
# 반복 : 184, 에러 : 0.12635736959055066, 승리 : 58, 승리비율 : 31.351351351351354
# 반복 : 185, 에러 : 0.12581493612378836, 승리 : 59, 승리비율 : 31.72043010752688
# 반복 : 186, 에러 : 0.18530823197215796, 승리 : 59, 승리비율 : 31.550802139037433
# 반복 : 187, 에러 : 0.18177103251218796, 승리 : 59, 승리비율 : 31.382978723404253
# 반복 : 188, 에러 : 0.15942828264087439, 승리 : 60, 승리비율 : 31.746031746031743
# 반복 : 189, 에러 : 0.12180182244628668, 승리 : 60, 승리비율 : 31.57894736842105
# 반복 : 190, 에러 : 0.11285045370459557, 승리 : 61, 승리비율 : 31.93717277486911
# 반복 : 191, 에러 : 0.11557914409786463, 승리 : 61, 승리비율 : 31.770833333333332
# 반복 : 192, 에러 : 0.11902633868157864, 승리 : 61, 승리비율 : 31.606217616580313
# 반복 : 193, 에러 : 0.09216739190742373, 승리 : 62, 승리비율 : 31.958762886597935
# 반복 : 194, 에러 : 0.10643533058464527, 승리 : 63, 승리비율 : 32.30769230769231
# 반복 : 195, 에러 : 0.13506192155182362, 승리 : 64, 승리비율 : 32.6530612244898
# 반복 : 196, 에러 : 0.15282275155186653, 승리 : 64, 승리비율 : 32.48730964467005
# 반복 : 197, 에러 : 0.10302041471004486, 승리 : 65, 승리비율 : 32.82828282828283
# 반복 : 198, 에러 : 0.14846732653677464, 승리 : 65, 승리비율 : 32.663316582914575
# 반복 : 199, 에러 : 0.1877763494849205, 승리 : 66, 승리비율 : 33.0
# 반복 : 200, 에러 : 0.13738900935277343, 승리 : 67, 승리비율 : 33.33333333333333
# 반복 : 201, 에러 : 0.15340974554419518, 승리 : 67, 승리비율 : 33.16831683168317
# 반복 : 202, 에러 : 0.11288284789770842, 승리 : 68, 승리비율 : 33.497536945812804
# 반복 : 203, 에러 : 0.1380871911533177, 승리 : 69, 승리비율 : 33.82352941176471
# 반복 : 204, 에러 : 0.173246830701828, 승리 : 70, 승리비율 : 34.146341463414636
# 반복 : 205, 에러 : 0.16716894414275885, 승리 : 70, 승리비율 : 33.980582524271846
# 반복 : 206, 에러 : 0.13244890607893467, 승리 : 70, 승리비율 : 33.81642512077295
# 반복 : 207, 에러 : 0.12705028522759676, 승리 : 71, 승리비율 : 34.13461538461539
# 반복 : 208, 에러 : 0.1174114840105176, 승리 : 71, 승리비율 : 33.97129186602871
# 반복 : 209, 에러 : 0.14243355672806501, 승리 : 72, 승리비율 : 34.285714285714285
# 반복 : 210, 에러 : 0.1430411245673895, 승리 : 72, 승리비율 : 34.12322274881517
# 반복 : 211, 에러 : 0.10861330386251211, 승리 : 72, 승리비율 : 33.9622641509434
# 반복 : 212, 에러 : 0.15223295707255602, 승리 : 73, 승리비율 : 34.27230046948357
# 반복 : 213, 에러 : 0.12968689110130072, 승리 : 74, 승리비율 : 34.57943925233645
# 반복 : 214, 에러 : 0.15254631265997887, 승리 : 75, 승리비율 : 34.883720930232556
# 반복 : 215, 에러 : 0.13520401995629072, 승리 : 75, 승리비율 : 34.72222222222222
# 반복 : 216, 에러 : 0.1463596113026142, 승리 : 76, 승리비율 : 35.02304147465438
# 반복 : 217, 에러 : 0.12913802545517683, 승리 : 76, 승리비율 : 34.862385321100916
# 반복 : 218, 에러 : 0.1082327077165246, 승리 : 77, 승리비율 : 35.15981735159817
# 반복 : 219, 에러 : 0.1367088775150478, 승리 : 78, 승리비율 : 35.45454545454545
# 반복 : 220, 에러 : 0.11620975658297539, 승리 : 78, 승리비율 : 35.294117647058826
# 반복 : 221, 에러 : 0.1109553282149136, 승리 : 79, 승리비율 : 35.585585585585584
# 반복 : 222, 에러 : 0.07418610667809844, 승리 : 79, 승리비율 : 35.42600896860987
# 반복 : 223, 에러 : 0.1490280982106924, 승리 : 80, 승리비율 : 35.714285714285715
# 반복 : 224, 에러 : 0.09460924146696925, 승리 : 81, 승리비율 : 36.0
# 반복 : 225, 에러 : 0.11099753389135003, 승리 : 82, 승리비율 : 36.283185840707965
# 반복 : 226, 에러 : 0.10148403234779835, 승리 : 83, 승리비율 : 36.56387665198238
# 반복 : 227, 에러 : 0.08578572887927294, 승리 : 84, 승리비율 : 36.84210526315789
# 반복 : 228, 에러 : 0.08423438435420394, 승리 : 85, 승리비율 : 37.117903930131
# 반복 : 229, 에러 : 0.09404053306207061, 승리 : 85, 승리비율 : 36.95652173913043
# 반복 : 230, 에러 : 0.09398286929354072, 승리 : 85, 승리비율 : 36.79653679653679
# 반복 : 231, 에러 : 0.0922633521258831, 승리 : 85, 승리비율 : 36.637931034482754
# 반복 : 232, 에러 : 0.1121559995226562, 승리 : 86, 승리비율 : 36.9098712446352
# 반복 : 233, 에러 : 0.11134662944823503, 승리 : 86, 승리비율 : 36.75213675213676
# 반복 : 234, 에러 : 0.08206689869984984, 승리 : 86, 승리비율 : 36.59574468085106
# 반복 : 235, 에러 : 0.0975005435757339, 승리 : 86, 승리비율 : 36.440677966101696
# 반복 : 236, 에러 : 0.10029989387840033, 승리 : 87, 승리비율 : 36.708860759493675
# 반복 : 237, 에러 : 0.0940355104394257, 승리 : 87, 승리비율 : 36.554621848739494
# 반복 : 238, 에러 : 0.07864047400653362, 승리 : 87, 승리비율 : 36.40167364016737
# 반복 : 239, 에러 : 0.10741205373778939, 승리 : 87, 승리비율 : 36.25
# 반복 : 240, 에러 : 0.09630054794251919, 승리 : 87, 승리비율 : 36.09958506224066
# 반복 : 241, 에러 : 0.10915394779294729, 승리 : 87, 승리비율 : 35.9504132231405
# 반복 : 242, 에러 : 0.11315216217190027, 승리 : 87, 승리비율 : 35.80246913580247
# 반복 : 243, 에러 : 0.12434917967766523, 승리 : 88, 승리비율 : 36.0655737704918
# 반복 : 244, 에러 : 0.12946113757789135, 승리 : 89, 승리비율 : 36.3265306122449
# 반복 : 245, 에러 : 0.11410030722618103, 승리 : 89, 승리비율 : 36.17886178861789
# 반복 : 246, 에러 : 0.13811397459357977, 승리 : 89, 승리비율 : 36.032388663967616
# 반복 : 247, 에러 : 0.10493575781583786, 승리 : 90, 승리비율 : 36.29032258064516
# 반복 : 248, 에러 : 0.08275373233482242, 승리 : 90, 승리비율 : 36.144578313253014
# 반복 : 249, 에러 : 0.13219287991523743, 승리 : 91, 승리비율 : 36.4
# 반복 : 250, 에러 : 0.09112114878371358, 승리 : 91, 승리비율 : 36.254980079681275
# 반복 : 251, 에러 : 0.10616053408011794, 승리 : 91, 승리비율 : 36.11111111111111
# 반복 : 252, 에러 : 0.17199210450053215, 승리 : 92, 승리비율 : 36.36363636363637
# 반복 : 253, 에러 : 0.09945899620652199, 승리 : 92, 승리비율 : 36.22047244094488
# 반복 : 254, 에러 : 0.11065896973013878, 승리 : 92, 승리비율 : 36.07843137254902
# 반복 : 255, 에러 : 0.07465596916154027, 승리 : 93, 승리비율 : 36.328125
# 반복 : 256, 에러 : 0.07847813749685884, 승리 : 94, 승리비율 : 36.57587548638132
# 반복 : 257, 에러 : 0.09658945258706808, 승리 : 94, 승리비율 : 36.434108527131784
# 반복 : 258, 에러 : 0.11930716503411531, 승리 : 95, 승리비율 : 36.67953667953668
# 반복 : 259, 에러 : 0.10993897914886475, 승리 : 95, 승리비율 : 36.53846153846153
# 반복 : 260, 에러 : 0.11617002310231328, 승리 : 95, 승리비율 : 36.39846743295019
# 반복 : 261, 에러 : 0.08944500051438808, 승리 : 95, 승리비율 : 36.25954198473282
# 반복 : 262, 에러 : 0.0793285183608532, 승리 : 95, 승리비율 : 36.12167300380228
# 반복 : 263, 에러 : 0.07092405506409705, 승리 : 96, 승리비율 : 36.36363636363637
# 반복 : 264, 에러 : 0.06621141731739044, 승리 : 96, 승리비율 : 36.22641509433962
# 반복 : 265, 에러 : 0.07874376652762294, 승리 : 97, 승리비율 : 36.46616541353384
# 반복 : 266, 에러 : 0.09320242516696453, 승리 : 98, 승리비율 : 36.70411985018727
# 반복 : 267, 에러 : 0.11588087724521756, 승리 : 98, 승리비율 : 36.56716417910448
# 반복 : 268, 에러 : 0.10389758460223675, 승리 : 98, 승리비율 : 36.43122676579926
# 반복 : 269, 에러 : 0.07831870159134269, 승리 : 99, 승리비율 : 36.666666666666664
# 반복 : 270, 에러 : 0.08313994714990258, 승리 : 100, 승리비율 : 36.90036900369004
# 반복 : 271, 에러 : 0.08048797491937876, 승리 : 100, 승리비율 : 36.76470588235294
# 반복 : 272, 에러 : 0.09030830441042781, 승리 : 101, 승리비율 : 36.996336996337
# 반복 : 273, 에러 : 0.0860517006367445, 승리 : 101, 승리비율 : 36.86131386861314
# 반복 : 274, 에러 : 0.0898644020780921, 승리 : 102, 승리비율 : 37.09090909090909
# 반복 : 275, 에러 : 0.07015872094780207, 승리 : 103, 승리비율 : 37.31884057971014
# 반복 : 276, 에러 : 0.09112858073785901, 승리 : 104, 승리비율 : 37.545126353790614
# 반복 : 277, 에러 : 0.06994100101292133, 승리 : 104, 승리비율 : 37.410071942446045
# 반복 : 278, 에러 : 0.055512514896690845, 승리 : 105, 승리비율 : 37.634408602150536
# 반복 : 279, 에러 : 0.10780748259276152, 승리 : 106, 승리비율 : 37.857142857142854
# 반복 : 280, 에러 : 0.06610073568299413, 승리 : 107, 승리비율 : 38.07829181494662
# 반복 : 281, 에러 : 0.04875740921124816, 승리 : 108, 승리비율 : 38.297872340425535
# 반복 : 282, 에러 : 0.054954391438513994, 승리 : 108, 승리비율 : 38.16254416961131
# 반복 : 283, 에러 : 0.08139086375012994, 승리 : 109, 승리비율 : 38.38028169014084
# 반복 : 284, 에러 : 0.051066598389297724, 승리 : 110, 승리비율 : 38.59649122807017
# 반복 : 285, 에러 : 0.06857844907790422, 승리 : 111, 승리비율 : 38.81118881118881
# 반복 : 286, 에러 : 0.0659461875911802, 승리 : 111, 승리비율 : 38.67595818815331
# 반복 : 287, 에러 : 0.059450644766911864, 승리 : 112, 승리비율 : 38.88888888888889
# 반복 : 288, 에러 : 0.10877798730507493, 승리 : 113, 승리비율 : 39.10034602076124
# 반복 : 289, 에러 : 0.08855086215771735, 승리 : 113, 승리비율 : 38.96551724137931
# 반복 : 290, 에러 : 0.07269050320610404, 승리 : 113, 승리비율 : 38.83161512027492
# 반복 : 291, 에러 : 0.1280720718204975, 승리 : 114, 승리비율 : 39.04109589041096
# 반복 : 292, 에러 : 0.09335832530632615, 승리 : 115, 승리비율 : 39.249146757679185
# 반복 : 293, 에러 : 0.06459689512848854, 승리 : 116, 승리비율 : 39.455782312925166
# 반복 : 294, 에러 : 0.07065159361809492, 승리 : 117, 승리비율 : 39.66101694915255
# 반복 : 295, 에러 : 0.09003660432063043, 승리 : 118, 승리비율 : 39.86486486486486
# 반복 : 296, 에러 : 0.08225602400489151, 승리 : 119, 승리비율 : 40.06734006734007
# 반복 : 297, 에러 : 0.06051682820543647, 승리 : 120, 승리비율 : 40.26845637583892
# 반복 : 298, 에러 : 0.08215912710875273, 승리 : 121, 승리비율 : 40.468227424749166
# 반복 : 299, 에러 : 0.05253240396268666, 승리 : 122, 승리비율 : 40.666666666666664
# 반복 : 300, 에러 : 0.065310831181705, 승리 : 123, 승리비율 : 40.863787375415285
# 반복 : 301, 에러 : 0.056209884118288755, 승리 : 124, 승리비율 : 41.05960264900662
# 반복 : 302, 에러 : 0.04582923324778676, 승리 : 124, 승리비율 : 40.92409240924093
# 반복 : 303, 에러 : 0.05148363392800093, 승리 : 125, 승리비율 : 41.118421052631575
# 반복 : 304, 에러 : 0.07153231743723154, 승리 : 126, 승리비율 : 41.31147540983607
# 반복 : 305, 에러 : 0.06906783347949386, 승리 : 127, 승리비율 : 41.50326797385621
# 반복 : 306, 에러 : 0.08252632571384311, 승리 : 128, 승리비율 : 41.69381107491857
# 반복 : 307, 에러 : 0.0571413601282984, 승리 : 129, 승리비율 : 41.883116883116884
# 반복 : 308, 에러 : 0.09174032090231776, 승리 : 129, 승리비율 : 41.74757281553398
# 반복 : 309, 에러 : 0.05292468215338886, 승리 : 130, 승리비율 : 41.935483870967744
# 반복 : 310, 에러 : 0.0875530457124114, 승리 : 130, 승리비율 : 41.80064308681672
# 반복 : 311, 에러 : 0.08150228718295693, 승리 : 130, 승리비율 : 41.66666666666667
# 반복 : 312, 에러 : 0.0696224058046937, 승리 : 131, 승리비율 : 41.853035143769965
# 반복 : 313, 에러 : 0.06711994670331478, 승리 : 131, 승리비율 : 41.71974522292994
# 반복 : 314, 에러 : 0.0746140731498599, 승리 : 132, 승리비율 : 41.904761904761905
# 반복 : 315, 에러 : 0.09406879171729088, 승리 : 133, 승리비율 : 42.08860759493671
# 반복 : 316, 에러 : 0.06424390617758036, 승리 : 134, 승리비율 : 42.27129337539432
# 반복 : 317, 에러 : 0.05138080008327961, 승리 : 135, 승리비율 : 42.45283018867924
# 반복 : 318, 에러 : 0.06826119718607515, 승리 : 135, 승리비율 : 42.31974921630094
# 반복 : 319, 에러 : 0.06965812551788986, 승리 : 136, 승리비율 : 42.5
# 반복 : 320, 에러 : 0.0731776321772486, 승리 : 137, 승리비율 : 42.679127725856695
# 반복 : 321, 에러 : 0.08035871246829629, 승리 : 138, 승리비율 : 42.857142857142854
# 반복 : 322, 에러 : 0.08039591065607965, 승리 : 139, 승리비율 : 43.034055727554176
# 반복 : 323, 에러 : 0.07436299882829189, 승리 : 140, 승리비율 : 43.20987654320987
# 반복 : 324, 에러 : 0.06019179127179086, 승리 : 141, 승리비율 : 43.38461538461538
# 반복 : 325, 에러 : 0.04590598098002374, 승리 : 142, 승리비율 : 43.558282208588956
# 반복 : 326, 에러 : 0.05771568091586232, 승리 : 143, 승리비율 : 43.730886850152906
# 반복 : 327, 에러 : 0.043694835621863604, 승리 : 144, 승리비율 : 43.90243902439025
# 반복 : 328, 에러 : 0.07447969890199602, 승리 : 145, 승리비율 : 44.07294832826747
# 반복 : 329, 에러 : 0.06976467766799033, 승리 : 146, 승리비율 : 44.24242424242424
# 반복 : 330, 에러 : 0.06380534870550036, 승리 : 146, 승리비율 : 44.10876132930513
# 반복 : 331, 에러 : 0.077826295979321, 승리 : 146, 승리비율 : 43.97590361445783
# 반복 : 332, 에러 : 0.06802750308997929, 승리 : 147, 승리비율 : 44.14414414414414
# 반복 : 333, 에러 : 0.04823557334020734, 승리 : 148, 승리비율 : 44.31137724550898
# 반복 : 334, 에러 : 0.03992744954302907, 승리 : 149, 승리비율 : 44.47761194029851
# 반복 : 335, 에러 : 0.04094769980292767, 승리 : 149, 승리비율 : 44.345238095238095
# 반복 : 336, 에러 : 0.056740938453003764, 승리 : 150, 승리비율 : 44.510385756676556
# 반복 : 337, 에러 : 0.05838401801884174, 승리 : 151, 승리비율 : 44.67455621301775
# 반복 : 338, 에러 : 0.037439605221152306, 승리 : 152, 승리비율 : 44.83775811209439
# 반복 : 339, 에러 : 0.051992311142385006, 승리 : 153, 승리비율 : 45.0
# 반복 : 340, 에러 : 0.05850158375687897, 승리 : 154, 승리비율 : 45.16129032258064
# 반복 : 341, 에러 : 0.06405495153740048, 승리 : 154, 승리비율 : 45.02923976608187
# 반복 : 342, 에러 : 0.04852772387675941, 승리 : 155, 승리비율 : 45.18950437317784
# 반복 : 343, 에러 : 0.07600265787914395, 승리 : 156, 승리비율 : 45.348837209302324
# 반복 : 344, 에러 : 0.05183477629907429, 승리 : 157, 승리비율 : 45.507246376811594
# 반복 : 345, 에러 : 0.05402099550701678, 승리 : 158, 승리비율 : 45.664739884393065
# 반복 : 346, 에러 : 0.06558158970437944, 승리 : 158, 승리비율 : 45.53314121037464
# 반복 : 347, 에러 : 0.06747014354914427, 승리 : 159, 승리비율 : 45.689655172413794
# 반복 : 348, 에러 : 0.07591384602710605, 승리 : 160, 승리비율 : 45.845272206303726
# 반복 : 349, 에러 : 0.05224354611709714, 승리 : 161, 승리비율 : 46.0
# 반복 : 350, 에러 : 0.0393209932371974, 승리 : 161, 승리비율 : 45.86894586894587
# 반복 : 351, 에러 : 0.04783208202570677, 승리 : 162, 승리비율 : 46.02272727272727
# 반복 : 352, 에러 : 0.057778185699135065, 승리 : 163, 승리비율 : 46.1756373937677
# 반복 : 353, 에러 : 0.04498825431801379, 승리 : 164, 승리비율 : 46.32768361581921
# 반복 : 354, 에러 : 0.028469927492551506, 승리 : 165, 승리비율 : 46.478873239436616
# 반복 : 355, 에러 : 0.03477070666849613, 승리 : 165, 승리비율 : 46.348314606741575
# 반복 : 356, 에러 : 0.03868200979195535, 승리 : 166, 승리비율 : 46.49859943977591
# 반복 : 357, 에러 : 0.032699874602258205, 승리 : 167, 승리비율 : 46.64804469273743
# 반복 : 358, 에러 : 0.033852706430479884, 승리 : 168, 승리비율 : 46.796657381615596
# 반복 : 359, 에러 : 0.03214091691188514, 승리 : 169, 승리비율 : 46.94444444444444
# 반복 : 360, 에러 : 0.03315580519847572, 승리 : 170, 승리비율 : 47.091412742382275
# 반복 : 361, 에러 : 0.03192237741313875, 승리 : 171, 승리비율 : 47.23756906077348
# 반복 : 362, 에러 : 0.027351397089660168, 승리 : 172, 승리비율 : 47.38292011019284
# 반복 : 363, 에러 : 0.03326626494526863, 승리 : 173, 승리비율 : 47.527472527472526
# 반복 : 364, 에러 : 0.0239550843834877, 승리 : 174, 승리비율 : 47.671232876712324
# 반복 : 365, 에러 : 0.04353367444127798, 승리 : 175, 승리비율 : 47.81420765027322
# 반복 : 366, 에러 : 0.031116751953959465, 승리 : 176, 승리비율 : 47.956403269754766
# 반복 : 367, 에러 : 0.023239271598868072, 승리 : 177, 승리비율 : 48.09782608695652
# 반복 : 368, 에러 : 0.024861737270839512, 승리 : 178, 승리비율 : 48.23848238482385
# 반복 : 369, 에러 : 0.0320166009478271, 승리 : 179, 승리비율 : 48.37837837837838
# 반복 : 370, 에러 : 0.031004087533801794, 승리 : 180, 승리비율 : 48.517520215633425
# 반복 : 371, 에러 : 0.02574370475485921, 승리 : 181, 승리비율 : 48.655913978494624
# 반복 : 372, 에러 : 0.017677563591860235, 승리 : 182, 승리비율 : 48.793565683646115
# 반복 : 373, 에러 : 0.018494582502171397, 승리 : 183, 승리비율 : 48.93048128342246
# 반복 : 374, 에러 : 0.022103083203546703, 승리 : 184, 승리비율 : 49.06666666666666
# 반복 : 375, 에러 : 0.01785317319445312, 승리 : 185, 승리비율 : 49.202127659574465
# 반복 : 376, 에러 : 0.018923204042948782, 승리 : 186, 승리비율 : 49.3368700265252
# 반복 : 377, 에러 : 0.019465563935227692, 승리 : 187, 승리비율 : 49.47089947089947
# 반복 : 378, 에러 : 0.017590724281035364, 승리 : 188, 승리비율 : 49.6042216358839
# 반복 : 379, 에러 : 0.01677881577052176, 승리 : 189, 승리비율 : 49.73684210526316
# 반복 : 380, 에러 : 0.02136605279520154, 승리 : 190, 승리비율 : 49.86876640419948
# 반복 : 381, 에러 : 0.015949658351019025, 승리 : 191, 승리비율 : 50.0
# 반복 : 382, 에러 : 0.016603485331870615, 승리 : 192, 승리비율 : 50.13054830287206
# 반복 : 383, 에러 : 0.02398828451987356, 승리 : 193, 승리비율 : 50.260416666666664
# 반복 : 384, 에러 : 0.019621759303845465, 승리 : 194, 승리비율 : 50.38961038961038
# 반복 : 385, 에러 : 0.02245606924407184, 승리 : 195, 승리비율 : 50.51813471502591
# 반복 : 386, 에러 : 0.021484202705323696, 승리 : 196, 승리비율 : 50.64599483204134
# 반복 : 387, 에러 : 0.0200407060328871, 승리 : 197, 승리비율 : 50.77319587628865
# 반복 : 388, 에러 : 0.016684549278579652, 승리 : 198, 승리비율 : 50.899742930591266
# 반복 : 389, 에러 : 0.011287198401987553, 승리 : 199, 승리비율 : 51.02564102564102
# 반복 : 390, 에러 : 0.012987179798074067, 승리 : 200, 승리비율 : 51.150895140664964
# 반복 : 391, 에러 : 0.023577501880936325, 승리 : 200, 승리비율 : 51.02040816326531
# 반복 : 392, 에러 : 0.019292884971946478, 승리 : 201, 승리비율 : 51.14503816793893
# 반복 : 393, 에러 : 0.01420518138911575, 승리 : 202, 승리비율 : 51.26903553299492
# 반복 : 394, 에러 : 0.016482398146763444, 승리 : 203, 승리비율 : 51.392405063291136
# 반복 : 395, 에러 : 0.013927329913713038, 승리 : 204, 승리비율 : 51.515151515151516
# 반복 : 396, 에러 : 0.012770868721418083, 승리 : 205, 승리비율 : 51.63727959697732
# 반복 : 397, 에러 : 0.011883637169376016, 승리 : 206, 승리비율 : 51.75879396984925
# 반복 : 398, 에러 : 0.009846752567682415, 승리 : 207, 승리비율 : 51.8796992481203
# 반복 : 399, 에러 : 0.01000045076943934, 승리 : 208, 승리비율 : 52.0
# 반복 : 400, 에러 : 0.016067861462943256, 승리 : 209, 승리비율 : 52.119700748129674
# 반복 : 401, 에러 : 0.010495892376638949, 승리 : 210, 승리비율 : 52.23880597014925
# 반복 : 402, 에러 : 0.03213081287685782, 승리 : 211, 승리비율 : 52.357320099255574
# 반복 : 403, 에러 : 0.029151456314139068, 승리 : 212, 승리비율 : 52.475247524752476
# 반복 : 404, 에러 : 0.022435665130615234, 승리 : 213, 승리비율 : 52.59259259259259
# 반복 : 405, 에러 : 0.028751657460816205, 승리 : 213, 승리비율 : 52.463054187192114
# 반복 : 406, 에러 : 0.014747948502190411, 승리 : 213, 승리비율 : 52.33415233415234
# 반복 : 407, 에러 : 0.025600801804102957, 승리 : 213, 승리비율 : 52.20588235294118
# 반복 : 408, 에러 : 0.021014789468608797, 승리 : 214, 승리비율 : 52.32273838630807
# 반복 : 409, 에러 : 0.012597089866176248, 승리 : 215, 승리비율 : 52.4390243902439
# 반복 : 410, 에러 : 0.011649920314084738, 승리 : 215, 승리비율 : 52.311435523114355
# 반복 : 411, 에러 : 0.011893584043718874, 승리 : 216, 승리비율 : 52.42718446601942
# 반복 : 412, 에러 : 0.01042721449630335, 승리 : 217, 승리비율 : 52.54237288135594
# 반복 : 413, 에러 : 0.00903387734433636, 승리 : 218, 승리비율 : 52.65700483091788
# 반복 : 414, 에러 : 0.009578976547345519, 승리 : 219, 승리비율 : 52.77108433734939
# 반복 : 415, 에러 : 0.008354648045497015, 승리 : 220, 승리비율 : 52.88461538461539
# 반복 : 416, 에러 : 0.008996763383038342, 승리 : 221, 승리비율 : 52.99760191846523
# 반복 : 417, 에러 : 0.015445855853613466, 승리 : 222, 승리비율 : 53.110047846889955
# 반복 : 418, 에러 : 0.006977286597248167, 승리 : 223, 승리비율 : 53.22195704057279
# 반복 : 419, 에러 : 0.00739795999834314, 승리 : 224, 승리비율 : 53.333333333333336
# 반복 : 420, 에러 : 0.013756899686995894, 승리 : 224, 승리비율 : 53.20665083135392
# 반복 : 421, 에러 : 0.011269912240095437, 승리 : 225, 승리비율 : 53.317535545023695
# 반복 : 422, 에러 : 0.005116996442666277, 승리 : 226, 승리비율 : 53.42789598108747
# 반복 : 423, 에러 : 0.00647780709550716, 승리 : 227, 승리비율 : 53.5377358490566
# 반복 : 424, 에러 : 0.013007241126615554, 승리 : 228, 승리비율 : 53.64705882352941
# 반복 : 425, 에러 : 0.012268967286217958, 승리 : 229, 승리비율 : 53.755868544600936
# 반복 : 426, 에러 : 0.005627207545330748, 승리 : 230, 승리비율 : 53.86416861826698
# 반복 : 427, 에러 : 0.013420229079201818, 승리 : 231, 승리비율 : 53.97196261682243
# 반복 : 428, 에러 : 0.011762736161472276, 승리 : 232, 승리비율 : 54.07925407925408
# 반복 : 429, 에러 : 0.010437957476824522, 승리 : 233, 승리비율 : 54.18604651162791
# 반복 : 430, 에러 : 0.007004491315456107, 승리 : 234, 승리비율 : 54.292343387471
# 반복 : 431, 에러 : 0.013767764496151358, 승리 : 235, 승리비율 : 54.39814814814815
# 반복 : 432, 에러 : 0.010623898007906973, 승리 : 236, 승리비율 : 54.50346420323326
# 반복 : 433, 에러 : 0.007125977834220976, 승리 : 237, 승리비율 : 54.60829493087558
# 반복 : 434, 에러 : 0.005857817246578634, 승리 : 238, 승리비율 : 54.71264367816092
# 반복 : 435, 에러 : 0.006487407605163753, 승리 : 238, 승리비율 : 54.58715596330275
# 반복 : 436, 에러 : 0.006031188240740448, 승리 : 239, 승리비율 : 54.69107551487414
# 반복 : 437, 에러 : 0.0136662196891848, 승리 : 240, 승리비율 : 54.794520547945204
# 반복 : 438, 에러 : 0.010074689984321594, 승리 : 241, 승리비율 : 54.89749430523918
# 반복 : 439, 에러 : 0.010802448552567512, 승리 : 242, 승리비율 : 55.00000000000001
# 반복 : 440, 에러 : 0.009751040837727487, 승리 : 243, 승리비율 : 55.10204081632652
# 반복 : 441, 에러 : 0.01173597521847114, 승리 : 244, 승리비율 : 55.203619909502265
# 반복 : 442, 에러 : 0.009034563961904496, 승리 : 245, 승리비율 : 55.30474040632054
# 반복 : 443, 에러 : 0.015104584919754416, 승리 : 246, 승리비율 : 55.4054054054054
# 반복 : 444, 에러 : 0.011596036201808602, 승리 : 246, 승리비율 : 55.28089887640449
# 반복 : 445, 에러 : 0.011408818245399743, 승리 : 246, 승리비율 : 55.15695067264574
# 반복 : 446, 에러 : 0.012396857840940356, 승리 : 246, 승리비율 : 55.033557046979865
# 반복 : 447, 에러 : 0.008035295701120049, 승리 : 247, 승리비율 : 55.13392857142857
# 반복 : 448, 에러 : 0.010503758152481169, 승리 : 248, 승리비율 : 55.233853006681514
# 반복 : 449, 에러 : 0.011893169430550188, 승리 : 249, 승리비율 : 55.333333333333336
# 반복 : 450, 에러 : 0.006813137035351247, 승리 : 250, 승리비율 : 55.432372505543235
# 반복 : 451, 에러 : 0.0065606056014075875, 승리 : 251, 승리비율 : 55.530973451327434
# 반복 : 452, 에러 : 0.008755366259720176, 승리 : 252, 승리비율 : 55.62913907284768
# 반복 : 453, 에러 : 0.006042196851922199, 승리 : 253, 승리비율 : 55.72687224669603
# 반복 : 454, 에러 : 0.005065346020273864, 승리 : 253, 승리비율 : 55.604395604395606
# 반복 : 455, 에러 : 0.004968074848875403, 승리 : 254, 승리비율 : 55.70175438596491
# 반복 : 456, 에러 : 0.008993919298518449, 승리 : 255, 승리비율 : 55.798687089715536
# 반복 : 457, 에러 : 0.006102495972299948, 승리 : 256, 승리비율 : 55.895196506550214
# 반복 : 458, 에러 : 0.003879562660586089, 승리 : 257, 승리비율 : 55.99128540305011
# 반복 : 459, 에러 : 0.007247155939694494, 승리 : 258, 승리비율 : 56.086956521739125
# 반복 : 460, 에러 : 0.006308938638539985, 승리 : 259, 승리비율 : 56.182212581344906
# 반복 : 461, 에러 : 0.005428101430879906, 승리 : 260, 승리비율 : 56.27705627705628
# 반복 : 462, 에러 : 0.006989981775404885, 승리 : 261, 승리비율 : 56.371490280777536
# 반복 : 463, 에러 : 0.004321219370467588, 승리 : 262, 승리비율 : 56.46551724137932
# 반복 : 464, 에러 : 0.004779862705618143, 승리 : 263, 승리비율 : 56.55913978494623
# 반복 : 465, 에러 : 0.009054407040821388, 승리 : 264, 승리비율 : 56.65236051502146
# 반복 : 466, 에러 : 0.005592501605860889, 승리 : 265, 승리비율 : 56.74518201284796
# 반복 : 467, 에러 : 0.06590188306290656, 승리 : 266, 승리비율 : 56.837606837606835
# 반복 : 468, 에러 : 0.0958560882427264, 승리 : 266, 승리비율 : 56.71641791044776
# 반복 : 469, 에러 : 0.09505326300859451, 승리 : 267, 승리비율 : 56.80851063829787
# 반복 : 470, 에러 : 0.047237975406460464, 승리 : 268, 승리비율 : 56.90021231422505
# 반복 : 471, 에러 : 0.06853297038469464, 승리 : 268, 승리비율 : 56.779661016949156
# 반복 : 472, 에러 : 0.08950480632483959, 승리 : 269, 승리비율 : 56.87103594080338
# 반복 : 473, 에러 : 0.05674848554190248, 승리 : 269, 승리비율 : 56.75105485232067
# 반복 : 474, 에러 : 0.11952316761016846, 승리 : 270, 승리비율 : 56.84210526315789
# 반복 : 475, 에러 : 0.09061987069435418, 승리 : 271, 승리비율 : 56.9327731092437
# 반복 : 476, 에러 : 0.023854987928643823, 승리 : 271, 승리비율 : 56.81341719077568
# 반복 : 477, 에러 : 0.07931541337165982, 승리 : 272, 승리비율 : 56.903765690376574
# 반복 : 478, 에러 : 0.0830461559817195, 승리 : 272, 승리비율 : 56.78496868475992
# 반복 : 479, 에러 : 0.02781190408859402, 승리 : 273, 승리비율 : 56.875
# 반복 : 480, 에러 : 0.10496981185860932, 승리 : 274, 승리비율 : 56.96465696465697
# 반복 : 481, 에러 : 0.12148437486030161, 승리 : 275, 승리비율 : 57.05394190871369
# 반복 : 482, 에러 : 0.04428668518085033, 승리 : 276, 승리비율 : 57.14285714285714
# 반복 : 483, 에러 : 0.08861061255447567, 승리 : 277, 승리비율 : 57.231404958677686
# 반복 : 484, 에러 : 0.05050772521644831, 승리 : 278, 승리비율 : 57.319587628865975
# 반복 : 485, 에러 : 0.05789124651346356, 승리 : 279, 승리비율 : 57.407407407407405
# 반복 : 486, 에러 : 0.063020427711308, 승리 : 280, 승리비율 : 57.49486652977412
# 반복 : 487, 에러 : 0.052368867909535766, 승리 : 281, 승리비율 : 57.58196721311475
# 반복 : 488, 에러 : 0.03692040377063677, 승리 : 282, 승리비율 : 57.668711656441715
# 반복 : 489, 에러 : 0.03584279550705105, 승리 : 283, 승리비율 : 57.75510204081633
# 반복 : 490, 에러 : 0.03710149344988167, 승리 : 284, 승리비율 : 57.841140529531565
# 반복 : 491, 에러 : 0.04123043152503669, 승리 : 285, 승리비율 : 57.92682926829268
# 반복 : 492, 에러 : 0.04524456919170916, 승리 : 286, 승리비율 : 58.012170385395535
# 반복 : 493, 에러 : 0.060171013697981834, 승리 : 287, 승리비율 : 58.097165991902834
# 반복 : 494, 에러 : 0.04443397815339267, 승리 : 288, 승리비율 : 58.18181818181818
# 반복 : 495, 에러 : 0.041659944923594594, 승리 : 289, 승리비율 : 58.266129032258064
# 반복 : 496, 에러 : 0.05530375079251826, 승리 : 290, 승리비율 : 58.35010060362173
# 반복 : 497, 에러 : 0.04550686734728515, 승리 : 291, 승리비율 : 58.43373493975904
# 반복 : 498, 에러 : 0.022121965186670423, 승리 : 292, 승리비율 : 58.517034068136276
# 반복 : 499, 에러 : 0.0267409048974514, 승리 : 292, 승리비율 : 58.4
# 반복 : 500, 에러 : 0.028081617085263133, 승리 : 293, 승리비율 : 58.48303393213573
# 반복 : 501, 에러 : 0.02957061619963497, 승리 : 294, 승리비율 : 58.56573705179283
# 반복 : 502, 에러 : 0.03168738563545048, 승리 : 295, 승리비율 : 58.64811133200796
# 반복 : 503, 에러 : 0.0350482432404533, 승리 : 296, 승리비율 : 58.730158730158735
# 반복 : 504, 에러 : 0.029364549671299756, 승리 : 296, 승리비율 : 58.61386138613861
# 반복 : 505, 에러 : 0.04841225198470056, 승리 : 297, 승리비율 : 58.69565217391305
# 반복 : 506, 에러 : 0.047352791647426784, 승리 : 298, 승리비율 : 58.777120315581854
# 반복 : 507, 에러 : 0.0375386334490031, 승리 : 299, 승리비율 : 58.85826771653543
# 반복 : 508, 에러 : 0.037991364719346166, 승리 : 300, 승리비율 : 58.93909626719057
# 반복 : 509, 에러 : 0.025470341555774212, 승리 : 301, 승리비율 : 59.01960784313726
# 반복 : 510, 에러 : 0.026404541567899287, 승리 : 302, 승리비율 : 59.099804305283755
# 반복 : 511, 에러 : 0.01747829612577334, 승리 : 303, 승리비율 : 59.1796875
# 반복 : 512, 에러 : 0.023449448752216995, 승리 : 304, 승리비율 : 59.25925925925925
# 반복 : 513, 에러 : 0.025108013476710767, 승리 : 305, 승리비율 : 59.33852140077821
# 반복 : 514, 에러 : 0.021926162880845368, 승리 : 306, 승리비율 : 59.417475728155345
# 반복 : 515, 에러 : 0.014193221286404878, 승리 : 307, 승리비율 : 59.496124031007746
# 반복 : 516, 에러 : 0.027547277510166168, 승리 : 308, 승리비율 : 59.57446808510638
# 반복 : 517, 에러 : 0.018706064205616713, 승리 : 309, 승리비율 : 59.65250965250966
# 반복 : 518, 에러 : 0.02830471273045987, 승리 : 310, 승리비율 : 59.73025048169557
# 반복 : 519, 에러 : 0.027254461543634534, 승리 : 311, 승리비율 : 59.80769230769231
# 반복 : 520, 에러 : 0.04073258058633655, 승리 : 312, 승리비율 : 59.88483685220729
# 반복 : 521, 에러 : 0.02248389442684129, 승리 : 313, 승리비율 : 59.961685823754785
# 반복 : 522, 에러 : 0.020934144675265998, 승리 : 314, 승리비율 : 60.038240917782026
# 반복 : 523, 에러 : 0.018085315474309027, 승리 : 315, 승리비율 : 60.1145038167939
# 반복 : 524, 에러 : 0.021306620095856488, 승리 : 316, 승리비율 : 60.1904761904762
# 반복 : 525, 에러 : 0.020876470836810768, 승리 : 316, 승리비율 : 60.07604562737643
# 반복 : 526, 에러 : 0.023030684678815305, 승리 : 317, 승리비율 : 60.151802656546494
# 반복 : 527, 에러 : 0.026681903167627752, 승리 : 318, 승리비율 : 60.22727272727273
# 반복 : 528, 에러 : 0.03656287177000195, 승리 : 319, 승리비율 : 60.30245746691871
# 반복 : 529, 에러 : 0.027478922507725656, 승리 : 320, 승리비율 : 60.37735849056604
# 반복 : 530, 에러 : 0.014545846730470657, 승리 : 321, 승리비율 : 60.451977401129945
# 반복 : 531, 에러 : 0.017521915899123996, 승리 : 322, 승리비율 : 60.526315789473685
# 반복 : 532, 에러 : 0.03025403490755707, 승리 : 323, 승리비율 : 60.60037523452158
# 반복 : 533, 에러 : 0.022866059269290417, 승리 : 324, 승리비율 : 60.67415730337079
# 반복 : 534, 에러 : 0.029069122159853578, 승리 : 325, 승리비율 : 60.747663551401864
# 반복 : 535, 에러 : 0.023694127856288105, 승리 : 326, 승리비율 : 60.820895522388064
# 반복 : 536, 에러 : 0.017402046883944422, 승리 : 327, 승리비율 : 60.893854748603346
# 반복 : 537, 에러 : 0.015942485420964658, 승리 : 327, 승리비율 : 60.78066914498142
# 반복 : 538, 에러 : 0.015433347434736788, 승리 : 328, 승리비율 : 60.85343228200371
# 반복 : 539, 에러 : 0.015506455267313868, 승리 : 329, 승리비율 : 60.92592592592593
# 반복 : 540, 에러 : 0.020738455408718437, 승리 : 330, 승리비율 : 60.998151571164506
# 반복 : 541, 에러 : 0.014044976094737649, 승리 : 331, 승리비율 : 61.07011070110702
# 반복 : 542, 에러 : 0.01080967258894816, 승리 : 332, 승리비율 : 61.141804788213626
# 반복 : 543, 에러 : 0.0269438010873273, 승리 : 333, 승리비율 : 61.21323529411765
# 반복 : 544, 에러 : 0.021590677904896438, 승리 : 333, 승리비율 : 61.100917431192656
# 반복 : 545, 에러 : 0.012612462742254138, 승리 : 334, 승리비율 : 61.172161172161175
# 반복 : 546, 에러 : 0.016709247895050794, 승리 : 334, 승리비율 : 61.06032906764168
# 반복 : 547, 에러 : 0.021739159943535924, 승리 : 335, 승리비율 : 61.131386861313864
# 반복 : 548, 에러 : 0.013052429188974202, 승리 : 336, 승리비율 : 61.20218579234973
# 반복 : 549, 에러 : 0.012228679785039276, 승리 : 336, 승리비율 : 61.09090909090909
# 반복 : 550, 에러 : 0.015875708893872797, 승리 : 337, 승리비율 : 61.16152450090744
# 반복 : 551, 에러 : 0.018011295818723738, 승리 : 338, 승리비율 : 61.23188405797102
# 반복 : 552, 에러 : 0.02379728085361421, 승리 : 339, 승리비율 : 61.30198915009042
# 반복 : 553, 에러 : 0.017377913871314377, 승리 : 340, 승리비율 : 61.371841155234655
# 반복 : 554, 에러 : 0.023243310512043536, 승리 : 341, 승리비율 : 61.44144144144145
# 반복 : 555, 에러 : 0.01618182531092316, 승리 : 342, 승리비율 : 61.51079136690647
# 반복 : 556, 에러 : 0.02402079594321549, 승리 : 343, 승리비율 : 61.57989228007181
# 반복 : 557, 에러 : 0.022185531561262906, 승리 : 344, 승리비율 : 61.648745519713266
# 반복 : 558, 에러 : 0.021315250545740128, 승리 : 345, 승리비율 : 61.71735241502684
# 반복 : 559, 에러 : 0.01217614091001451, 승리 : 346, 승리비율 : 61.78571428571429
# 반복 : 560, 에러 : 0.018242058344185352, 승리 : 347, 승리비율 : 61.853832442067734
# 반복 : 561, 에러 : 0.015087397070601583, 승리 : 348, 승리비율 : 61.92170818505338
# 반복 : 562, 에러 : 0.01565831748303026, 승리 : 349, 승리비율 : 61.98934280639432
# 반복 : 563, 에러 : 0.020854461705312133, 승리 : 350, 승리비율 : 62.056737588652474
# 반복 : 564, 에러 : 0.01930264162365347, 승리 : 350, 승리비율 : 61.94690265486725
# 반복 : 565, 에러 : 0.014056215761229396, 승리 : 351, 승리비율 : 62.014134275618375
# 반복 : 566, 에러 : 0.019062371109612286, 승리 : 352, 승리비율 : 62.08112874779541
# 반복 : 567, 에러 : 0.026954387314617634, 승리 : 352, 승리비율 : 61.97183098591549
# 반복 : 568, 에러 : 0.02168109209742397, 승리 : 353, 승리비율 : 62.038664323374334
# 반복 : 569, 에러 : 0.019500215770676732, 승리 : 353, 승리비율 : 61.929824561403514
# 반복 : 570, 에러 : 0.016972821089439094, 승리 : 354, 승리비율 : 61.99649737302977
# 반복 : 571, 에러 : 0.018572492757812142, 승리 : 355, 승리비율 : 62.06293706293706
# 반복 : 572, 에러 : 0.01586649753153324, 승리 : 356, 승리비율 : 62.129144851657934
# 반복 : 573, 에러 : 0.015681066492106766, 승리 : 357, 승리비율 : 62.19512195121951
# 반복 : 574, 에러 : 0.020527468295767903, 승리 : 358, 승리비율 : 62.26086956521739
# 반복 : 575, 에러 : 0.02315192436799407, 승리 : 359, 승리비율 : 62.326388888888886
# 반복 : 576, 에러 : 0.015707094338722527, 승리 : 360, 승리비율 : 62.391681109185434
# 반복 : 577, 에러 : 0.01680560811655596, 승리 : 361, 승리비율 : 62.45674740484429
# 반복 : 578, 에러 : 0.01594984345138073, 승리 : 362, 승리비율 : 62.52158894645942
# 반복 : 579, 에러 : 0.016965861665084958, 승리 : 363, 승리비율 : 62.58620689655172
# 반복 : 580, 에러 : 0.019320815335959196, 승리 : 364, 승리비율 : 62.65060240963856
# 반복 : 581, 에러 : 0.012678155035246164, 승리 : 365, 승리비율 : 62.7147766323024
# 반복 : 582, 에러 : 0.009656222944613546, 승리 : 366, 승리비율 : 62.778730703259
# 반복 : 583, 에러 : 0.013166112534236163, 승리 : 367, 승리비율 : 62.84246575342466
# 반복 : 584, 에러 : 0.01075131818652153, 승리 : 368, 승리비율 : 62.9059829059829
# 반복 : 585, 에러 : 0.012925237126182765, 승리 : 369, 승리비율 : 62.96928327645052
# 반복 : 586, 에러 : 0.011086285579949617, 승리 : 370, 승리비율 : 63.03236797274276
# 반복 : 587, 에러 : 0.012216243136208504, 승리 : 371, 승리비율 : 63.095238095238095
# 반복 : 588, 에러 : 0.012974710261914879, 승리 : 372, 승리비율 : 63.1578947368421
# 반복 : 589, 에러 : 0.010583062248770148, 승리 : 373, 승리비율 : 63.22033898305085
# 반복 : 590, 에러 : 0.012286762532312423, 승리 : 374, 승리비율 : 63.28257191201354
# 반복 : 591, 에러 : 0.011541270010638982, 승리 : 375, 승리비율 : 63.3445945945946
# 반복 : 592, 에러 : 0.011284968873951584, 승리 : 376, 승리비율 : 63.40640809443507
# 반복 : 593, 에러 : 0.008550375350750983, 승리 : 377, 승리비율 : 63.468013468013474
# 반복 : 594, 에러 : 0.009127664612606168, 승리 : 378, 승리비율 : 63.52941176470588
# 반복 : 595, 에러 : 0.010050423385109752, 승리 : 379, 승리비율 : 63.59060402684564
# 반복 : 596, 에러 : 0.011015425872756168, 승리 : 380, 승리비율 : 63.65159128978225
# 반복 : 597, 에러 : 0.008568531950004399, 승리 : 381, 승리비율 : 63.7123745819398
# 반복 : 598, 에러 : 0.010717212600866333, 승리 : 382, 승리비율 : 63.77295492487479
# 반복 : 599, 에러 : 0.009631466818973422, 승리 : 383, 승리비율 : 63.83333333333333
# 반복 : 600, 에러 : 0.010451511712744832, 승리 : 384, 승리비율 : 63.89351081530782
# 반복 : 601, 에러 : 0.010082576889544725, 승리 : 385, 승리비율 : 63.95348837209303
# 반복 : 602, 에러 : 0.00833610852714628, 승리 : 386, 승리비율 : 64.01326699834162
# 반복 : 603, 에러 : 0.009975692490115762, 승리 : 387, 승리비율 : 64.0728476821192
# 반복 : 604, 에러 : 0.007964919321238995, 승리 : 388, 승리비율 : 64.13223140495867
# 반복 : 605, 에러 : 0.009361667034681886, 승리 : 389, 승리비율 : 64.1914191419142
# 반복 : 606, 에러 : 0.01377440511714667, 승리 : 389, 승리비율 : 64.08566721581549
# 반복 : 607, 에러 : 0.01996670226799324, 승리 : 390, 승리비율 : 64.14473684210526
# 반복 : 608, 에러 : 0.01572159375064075, 승리 : 391, 승리비율 : 64.20361247947454
# 반복 : 609, 에러 : 0.02691340632736683, 승리 : 392, 승리비율 : 64.26229508196721
# 반복 : 610, 에러 : 0.015592149924486876, 승리 : 393, 승리비율 : 64.32078559738135
# 반복 : 611, 에러 : 0.022282220423221588, 승리 : 394, 승리비율 : 64.37908496732027
# 반복 : 612, 에러 : 0.015065501793287694, 승리 : 395, 승리비율 : 64.43719412724307
# 반복 : 613, 에러 : 0.013255360128823668, 승리 : 396, 승리비율 : 64.49511400651465
# 반복 : 614, 에러 : 0.01324145239777863, 승리 : 397, 승리비율 : 64.55284552845528
# 반복 : 615, 에러 : 0.016209726920351386, 승리 : 398, 승리비율 : 64.6103896103896
# 반복 : 616, 에러 : 0.0129375223768875, 승리 : 398, 승리비율 : 64.50567260940032
# 반복 : 617, 에러 : 0.029030143516138196, 승리 : 399, 승리비율 : 64.56310679611651
# 반복 : 618, 에러 : 0.015021461294963956, 승리 : 400, 승리비율 : 64.62035541195476
# 반복 : 619, 에러 : 0.01486734120408073, 승리 : 401, 승리비율 : 64.6774193548387
# 반복 : 620, 에러 : 0.01153116807108745, 승리 : 402, 승리비율 : 64.73429951690821
# 반복 : 621, 에러 : 0.014165639877319336, 승리 : 403, 승리비율 : 64.79099678456592
# 반복 : 622, 에러 : 0.013797424762742594, 승리 : 404, 승리비율 : 64.84751203852326
# 반복 : 623, 에러 : 0.012123615946620703, 승리 : 405, 승리비율 : 64.90384615384616
# 반복 : 624, 에러 : 0.016952550620771945, 승리 : 406, 승리비율 : 64.96
# 반복 : 625, 에러 : 0.009855824173428118, 승리 : 407, 승리비율 : 65.01597444089457
# 반복 : 626, 에러 : 0.01363899017451331, 승리 : 408, 승리비율 : 65.07177033492823
# 반복 : 627, 에러 : 0.011638950847554952, 승리 : 409, 승리비율 : 65.12738853503186
# 반복 : 628, 에러 : 0.014982780790887773, 승리 : 410, 승리비율 : 65.18282988871225
# 반복 : 629, 에러 : 0.010992853727657348, 승리 : 411, 승리비율 : 65.23809523809524
# 반복 : 630, 에러 : 0.010135174408787861, 승리 : 412, 승리비율 : 65.2931854199683
# 반복 : 631, 에러 : 0.008711867209058255, 승리 : 413, 승리비율 : 65.34810126582279
# 반복 : 632, 에러 : 0.0059820063470397145, 승리 : 414, 승리비율 : 65.40284360189574
# 반복 : 633, 에러 : 0.01082653715275228, 승리 : 415, 승리비율 : 65.45741324921136
# 반복 : 634, 에러 : 0.007516055804444477, 승리 : 416, 승리비율 : 65.51181102362204
# 반복 : 635, 에러 : 0.004393061593873426, 승리 : 417, 승리비율 : 65.56603773584906
# 반복 : 636, 에러 : 0.0068547677947208285, 승리 : 418, 승리비율 : 65.62009419152275
# 반복 : 637, 에러 : 0.007609365100506693, 승리 : 419, 승리비율 : 65.67398119122258
# 반복 : 638, 에러 : 0.00811538877314888, 승리 : 420, 승리비율 : 65.72769953051643
# 반복 : 639, 에러 : 0.007868517277529463, 승리 : 421, 승리비율 : 65.78125
# 반복 : 640, 에러 : 0.005054606561316177, 승리 : 422, 승리비율 : 65.83463338533542
# 반복 : 641, 에러 : 0.004463188350200653, 승리 : 423, 승리비율 : 65.88785046728972
# 반복 : 642, 에러 : 0.007205157628050074, 승리 : 424, 승리비율 : 65.94090202177294
# 반복 : 643, 에러 : 0.005119975772686303, 승리 : 425, 승리비율 : 65.99378881987577
# 반복 : 644, 에러 : 0.007011603767750785, 승리 : 426, 승리비율 : 66.04651162790698
# 반복 : 645, 에러 : 0.005971960898023099, 승리 : 427, 승리비율 : 66.09907120743034
# 반복 : 646, 에러 : 0.00646636268356815, 승리 : 428, 승리비율 : 66.15146831530139
# 반복 : 647, 에러 : 0.005790349387098104, 승리 : 429, 승리비율 : 66.20370370370371
# 반복 : 648, 에러 : 0.00418418351910077, 승리 : 430, 승리비율 : 66.2557781201849
# 반복 : 649, 에러 : 0.0038872192235430703, 승리 : 431, 승리비율 : 66.3076923076923
# 반복 : 650, 에러 : 0.005317521296092309, 승리 : 432, 승리비율 : 66.3594470046083
# 반복 : 651, 에러 : 0.002952132490463555, 승리 : 433, 승리비율 : 66.41104294478528
# 반복 : 652, 에러 : 0.004583810019539669, 승리 : 434, 승리비율 : 66.4624808575804
# 반복 : 653, 에러 : 0.007331916989642195, 승리 : 435, 승리비율 : 66.5137614678899
# 반복 : 654, 에러 : 0.006754489179002121, 승리 : 436, 승리비율 : 66.5648854961832
# 반복 : 655, 에러 : 0.004706609572167508, 승리 : 437, 승리비율 : 66.61585365853658
# 반복 : 656, 에러 : 0.002356989120016806, 승리 : 438, 승리비율 : 66.66666666666666
# 반복 : 657, 에러 : 0.00229803379625082, 승리 : 439, 승리비율 : 66.71732522796353
# 반복 : 658, 에러 : 0.0031442129547940567, 승리 : 440, 승리비율 : 66.76783004552352
# 반복 : 659, 에러 : 0.002502383169485256, 승리 : 441, 승리비율 : 66.81818181818183
# 반복 : 660, 에러 : 0.003236958393245004, 승리 : 442, 승리비율 : 66.86838124054462
# 반복 : 661, 에러 : 0.0022722329158568755, 승리 : 443, 승리비율 : 66.91842900302115
# 반복 : 662, 에러 : 0.004047839611303061, 승리 : 444, 승리비율 : 66.9683257918552
# 반복 : 663, 에러 : 0.002103971281030681, 승리 : 445, 승리비율 : 67.01807228915662
# 반복 : 664, 에러 : 0.003422349866013974, 승리 : 446, 승리비율 : 67.06766917293233
# 반복 : 665, 에러 : 0.0045419361122185364, 승리 : 447, 승리비율 : 67.11711711711712
# 반복 : 666, 에러 : 0.004320983134675771, 승리 : 448, 승리비율 : 67.1664167916042
# 반복 : 667, 에러 : 0.006638084392761812, 승리 : 449, 승리비율 : 67.21556886227546
# 반복 : 668, 에러 : 0.004000687273219228, 승리 : 450, 승리비율 : 67.2645739910314
# 반복 : 669, 에러 : 0.003990649420302361, 승리 : 451, 승리비율 : 67.31343283582089
# 반복 : 670, 에러 : 0.002749260369455442, 승리 : 452, 승리비율 : 67.36214605067065
# 반복 : 671, 에러 : 0.0029875577747588977, 승리 : 453, 승리비율 : 67.41071428571429
# 반복 : 672, 에러 : 0.0029373431170824915, 승리 : 454, 승리비율 : 67.4591381872214
# 반복 : 673, 에러 : 0.005254184507066384, 승리 : 455, 승리비율 : 67.50741839762611
# 반복 : 674, 에러 : 0.0055580091720912606, 승리 : 456, 승리비율 : 67.55555555555556
# 반복 : 675, 에러 : 0.004007117677247152, 승리 : 457, 승리비율 : 67.60355029585799
# 반복 : 676, 에러 : 0.005304271020577289, 승리 : 458, 승리비율 : 67.65140324963073
# 반복 : 677, 에러 : 0.006608847761526704, 승리 : 459, 승리비율 : 67.69911504424779
# 반복 : 678, 에러 : 0.003218119265511632, 승리 : 460, 승리비율 : 67.74668630338734
# 반복 : 679, 에러 : 0.002981455225381069, 승리 : 461, 승리비율 : 67.79411764705883
# 반복 : 680, 에러 : 0.0059394089330453426, 승리 : 462, 승리비율 : 67.84140969162996
# 반복 : 681, 에러 : 0.002430858963634819, 승리 : 463, 승리비율 : 67.88856304985337
# 반복 : 682, 에러 : 0.003972389429691248, 승리 : 464, 승리비율 : 67.93557833089312
# ...
# 반복 : 785, 에러 : 0.0017799140259739943, 승리 : 567, 승리비율 : 72.13740458015268
# 반복 : 786, 에러 : 0.0014537164097419009, 승리 : 568, 승리비율 : 72.1728081321474
# 반복 : 787, 에러 : 0.0015886743567534722, 승리 : 569, 승리비율 : 72.20812182741116
# 반복 : 788, 에러 : 0.001255217706784606, 승리 : 570, 승리비율 : 72.24334600760456
# 반복 : 789, 에러 : 0.0012679217179538682, 승리 : 571, 승리비율 : 72.27848101265822
# 반복 : 790, 에러 : 0.0011300423866487108, 승리 : 572, 승리비율 : 72.31352718078382
# 반복 : 791, 에러 : 0.0014747929672012106, 승리 : 573, 승리비율 : 72.34848484848484
# 반복 : 792, 에러 : 0.0015553728080703877, 승리 : 574, 승리비율 : 72.38335435056746
# 반복 : 793, 에러 : 0.0011554256452654954, 승리 : 575, 승리비율 : 72.41813602015114
# 반복 : 794, 에러 : 0.001550188819237519, 승리 : 576, 승리비율 : 72.45283018867924
# 반복 : 795, 에러 : 0.0011033227601728868, 승리 : 577, 승리비율 : 72.48743718592965
# 반복 : 796, 에러 : 0.0014480693207588047, 승리 : 578, 승리비율 : 72.5219573400251
# 반복 : 797, 에러 : 0.0016630283280392177, 승리 : 579, 승리비율 : 72.55639097744361
# 반복 : 798, 에러 : 0.0011824966204585508, 승리 : 580, 승리비율 : 72.5907384230288
# 반복 : 799, 에러 : 0.0010675582307158038, 승리 : 581, 승리비율 : 72.625
# 반복 : 800, 에러 : 0.0010676352685550228, 승리 : 582, 승리비율 : 72.65917602996255
# 반복 : 801, 에러 : 0.0012244051285961177, 승리 : 583, 승리비율 : 72.6932668329177
# 반복 : 802, 에러 : 0.0008368053786398377, 승리 : 584, 승리비율 : 72.72727272727273
# 반복 : 803, 에러 : 0.0012186665990157053, 승리 : 585, 승리비율 : 72.76119402985076
# 반복 : 804, 에러 : 0.000987985433312133, 승리 : 586, 승리비율 : 72.79503105590062
# 반복 : 805, 에러 : 0.0011218163854209706, 승리 : 587, 승리비율 : 72.8287841191067
# 반복 : 806, 에러 : 0.0011464328817964997, 승리 : 588, 승리비율 : 72.86245353159852
# 반복 : 807, 에러 : 0.000613406125921756, 승리 : 589, 승리비율 : 72.89603960396039
# 반복 : 808, 에러 : 0.0008042846311582252, 승리 : 590, 승리비율 : 72.92954264524104
# 반복 : 809, 에러 : 0.0008599325374234468, 승리 : 591, 승리비율 : 72.96296296296296
# 반복 : 810, 에러 : 0.0008767924155108631, 승리 : 592, 승리비율 : 72.99630086313194
# 반복 : 811, 에러 : 0.000646345732093323, 승리 : 593, 승리비율 : 73.0295566502463
# 반복 : 812, 에러 : 0.0006618793340749107, 승리 : 594, 승리비율 : 73.06273062730627
# 반복 : 813, 에러 : 0.0008666182911838405, 승리 : 595, 승리비율 : 73.09582309582309
# 반복 : 814, 에러 : 0.0007239971419039648, 승리 : 596, 승리비율 : 73.12883435582822
# 반복 : 815, 에러 : 0.0007990230042196345, 승리 : 597, 승리비율 : 73.16176470588235
# 반복 : 816, 에러 : 0.0009617338400857989, 승리 : 598, 승리비율 : 73.19461444308446
# 반복 : 817, 에러 : 0.0009214284218614921, 승리 : 599, 승리비율 : 73.22738386308069
# 반복 : 818, 에러 : 0.0007642562850378454, 승리 : 600, 승리비율 : 73.26007326007326
# 반복 : 819, 에러 : 0.0005008335538150277, 승리 : 601, 승리비율 : 73.29268292682927
# 반복 : 820, 에러 : 0.0006944535161892418, 승리 : 602, 승리비율 : 73.32521315468941
# 반복 : 821, 에러 : 0.0005940521223237738, 승리 : 603, 승리비율 : 73.35766423357664
# 반복 : 822, 에러 : 0.0006467922212323174, 승리 : 604, 승리비율 : 73.39003645200486
# 반복 : 823, 에러 : 0.00037326340134313796, 승리 : 605, 승리비율 : 73.42233009708737
# 반복 : 824, 에러 : 0.0006449993379646912, 승리 : 606, 승리비율 : 73.45454545454545
# 반복 : 825, 에러 : 0.0004864584461756749, 승리 : 607, 승리비율 : 73.48668280871671
# 반복 : 826, 에러 : 0.0004605051526596071, 승리 : 608, 승리비율 : 73.51874244256348
# 반복 : 827, 에러 : 0.0006464214275183622, 승리 : 609, 승리비율 : 73.55072463768117
# 반복 : 828, 에러 : 0.0004814362655451987, 승리 : 610, 승리비율 : 73.58262967430639
# 반복 : 829, 에러 : 0.00038796630906290375, 승리 : 611, 승리비율 : 73.6144578313253
# 반복 : 830, 에러 : 0.0005049421615694882, 승리 : 612, 승리비율 : 73.6462093862816
# 반복 : 831, 에러 : 0.0004811432463611709, 승리 : 613, 승리비율 : 73.67788461538461
# 반복 : 832, 에러 : 0.0005516627879842417, 승리 : 614, 승리비율 : 73.7094837935174
# 반복 : 833, 에러 : 0.0005508974754775409, 승리 : 615, 승리비율 : 73.7410071942446
# 반복 : 834, 에러 : 0.0002654718446137849, 승리 : 616, 승리비율 : 73.77245508982035
# 반복 : 835, 에러 : 0.0003721378216141602, 승리 : 617, 승리비율 : 73.80382775119617
# 반복 : 836, 에러 : 0.0012130068334954558, 승리 : 618, 승리비율 : 73.83512544802868
# 반복 : 837, 에러 : 0.0007864615618018433, 승리 : 619, 승리비율 : 73.86634844868735
# 반복 : 838, 에러 : 0.0005701306181435939, 승리 : 620, 승리비율 : 73.89749702026222
# 반복 : 839, 에러 : 0.0004177464288659394, 승리 : 621, 승리비율 : 73.92857142857143
# 반복 : 840, 에러 : 0.0007056258473312482, 승리 : 622, 승리비율 : 73.95957193816885
# 반복 : 841, 에러 : 0.0003855239901895402, 승리 : 623, 승리비율 : 73.99049881235155
# 반복 : 842, 에러 : 0.0005205273300816771, 승리 : 624, 승리비율 : 74.02135231316726
# 반복 : 843, 에러 : 0.000896260169611196, 승리 : 625, 승리비율 : 74.0521327014218
# 반복 : 844, 에러 : 0.0006234961037989706, 승리 : 626, 승리비율 : 74.0828402366864
# 반복 : 845, 에러 : 0.0010508508239581715, 승리 : 627, 승리비율 : 74.11347517730496
# 반복 : 846, 에러 : 0.0012391862910590135, 승리 : 628, 승리비율 : 74.14403778040142
# 반복 : 847, 에러 : 0.0005712866332032718, 승리 : 629, 승리비율 : 74.1745283018868
# 반복 : 848, 에러 : 0.0006293683836702257, 승리 : 630, 승리비율 : 74.20494699646643
# 반복 : 849, 에러 : 0.0008029612617974635, 승리 : 631, 승리비율 : 74.23529411764706
# 반복 : 850, 에러 : 0.0005995889796395204, 승리 : 632, 승리비율 : 74.26556991774383
# 반복 : 851, 에러 : 0.0005777937185484916, 승리 : 633, 승리비율 : 74.29577464788733
# 반복 : 852, 에러 : 0.0007104204742063303, 승리 : 634, 승리비율 : 74.32590855803049
# 반복 : 853, 에러 : 0.0015759171365061775, 승리 : 635, 승리비율 : 74.35597189695551
# 반복 : 854, 에러 : 0.0009511885509709828, 승리 : 636, 승리비율 : 74.3859649122807
# 반복 : 855, 에러 : 0.0008432138838543324, 승리 : 637, 승리비율 : 74.41588785046729
# 반복 : 856, 에러 : 0.0011441629721957725, 승리 : 638, 승리비율 : 74.44574095682613
# 반복 : 857, 에러 : 0.0009461511290282942, 승리 : 639, 승리비율 : 74.47552447552448
# 반복 : 858, 에러 : 0.0010376794343756046, 승리 : 640, 승리비율 : 74.50523864959256
# 반복 : 859, 에러 : 0.000814013896160759, 승리 : 641, 승리비율 : 74.53488372093024
# 반복 : 860, 에러 : 0.0009573760726198088, 승리 : 642, 승리비율 : 74.56445993031359
# 반복 : 861, 에러 : 0.0005868983644177206, 승리 : 643, 승리비율 : 74.5939675174014
# 반복 : 862, 에러 : 0.0006752847475581802, 승리 : 644, 승리비율 : 74.6234067207416
# 반복 : 863, 에러 : 0.0007800689782015979, 승리 : 645, 승리비율 : 74.65277777777779
# 반복 : 864, 에러 : 0.0007800774328643456, 승리 : 646, 승리비율 : 74.68208092485548
# 반복 : 865, 에러 : 0.0008384109605685808, 승리 : 647, 승리비율 : 74.71131639722863
# 반복 : 866, 에러 : 0.0008399765902140643, 승리 : 648, 승리비율 : 74.74048442906575
# 반복 : 867, 에러 : 0.0005542604958463926, 승리 : 649, 승리비율 : 74.76958525345621
# 반복 : 868, 에러 : 0.00048559096012468217, 승리 : 650, 승리비율 : 74.79861910241658
# 반복 : 869, 에러 : 0.0009366336889797822, 승리 : 651, 승리비율 : 74.82758620689656
# 반복 : 870, 에러 : 0.0008507163038302679, 승리 : 652, 승리비율 : 74.8564867967853
# 반복 : 871, 에러 : 0.0006124366300355177, 승리 : 653, 승리비율 : 74.88532110091744
# 반복 : 872, 에러 : 0.0006798730319133028, 승리 : 654, 승리비율 : 74.91408934707904
# 반복 : 873, 에러 : 0.0005174146062927321, 승리 : 655, 승리비율 : 74.94279176201373
# 반복 : 874, 에러 : 0.000532020134414779, 승리 : 656, 승리비율 : 74.97142857142856
# 반복 : 875, 에러 : 0.0006031439261278138, 승리 : 657, 승리비율 : 75.0
# 반복 : 876, 에러 : 0.0004906892827420961, 승리 : 658, 승리비율 : 75.0285062713797
# 반복 : 877, 에러 : 0.0007071130858093966, 승리 : 659, 승리비율 : 75.05694760820046
# 반복 : 878, 에러 : 0.000722305296221748, 승리 : 660, 승리비율 : 75.0853242320819
# 반복 : 879, 에러 : 0.0005485630135808606, 승리 : 661, 승리비율 : 75.11363636363636
# 반복 : 880, 에러 : 0.0005447076400741935, 승리 : 662, 승리비율 : 75.14188422247446
# 반복 : 881, 에러 : 0.00056358615620411, 승리 : 663, 승리비율 : 75.17006802721087
# 반복 : 882, 에러 : 0.0006897469247633126, 승리 : 664, 승리비율 : 75.19818799547
# 반복 : 883, 에러 : 0.0005961251044936944, 승리 : 665, 승리비율 : 75.22624434389141
# 반복 : 884, 에러 : 0.000554237707547145, 승리 : 666, 승리비율 : 75.2542372881356
# 반복 : 885, 에러 : 0.0006534825552080292, 승리 : 667, 승리비율 : 75.2821670428894
# 반복 : 886, 에러 : 0.0004866124399995897, 승리 : 668, 승리비율 : 75.31003382187149
# 반복 : 887, 에러 : 0.0005024165584472939, 승리 : 669, 승리비율 : 75.33783783783784
# 반복 : 888, 에러 : 0.0003572971054381924, 승리 : 670, 승리비율 : 75.36557930258716
# 반복 : 889, 에러 : 0.0004891948719887296, 승리 : 671, 승리비율 : 75.3932584269663
# 반복 : 890, 에러 : 0.0005127717813593335, 승리 : 672, 승리비율 : 75.42087542087542
# 반복 : 891, 에러 : 0.0004565337731037289, 승리 : 673, 승리비율 : 75.44843049327355
# 반복 : 892, 에러 : 0.0005794882454210892, 승리 : 674, 승리비율 : 75.47592385218364
# 반복 : 893, 에러 : 0.00036107286086917156, 승리 : 675, 승리비율 : 75.50335570469798
# 반복 : 894, 에러 : 0.0006005553441355005, 승리 : 676, 승리비율 : 75.53072625698324
# 반복 : 895, 에러 : 0.0005731984201702289, 승리 : 677, 승리비율 : 75.55803571428571
# 반복 : 896, 에러 : 0.0006574201797775459, 승리 : 678, 승리비율 : 75.58528428093646
# 반복 : 897, 에러 : 0.0009632446417526808, 승리 : 679, 승리비율 : 75.61247216035635
# 반복 : 898, 에러 : 0.0006623802000831347, 승리 : 680, 승리비율 : 75.63959955506118
# 반복 : 899, 에러 : 0.0005763226436101831, 승리 : 681, 승리비율 : 75.66666666666667
# 반복 : 900, 에러 : 0.0007844782558095176, 승리 : 682, 승리비율 : 75.69367369589345
# 반복 : 901, 에러 : 0.0008526499623258132, 승리 : 683, 승리비율 : 75.72062084257206
# 반복 : 902, 에러 : 0.0006084449232730549, 승리 : 684, 승리비율 : 75.74750830564784
# 반복 : 903, 에러 : 0.0004998669646738563, 승리 : 685, 승리비율 : 75.77433628318585
# 반복 : 904, 에러 : 0.0008493580462527461, 승리 : 686, 승리비율 : 75.80110497237568
# 반복 : 905, 에러 : 0.0007246926379593788, 승리 : 687, 승리비율 : 75.82781456953643
# 반복 : 906, 에러 : 0.000795428943092702, 승리 : 688, 승리비율 : 75.85446527012127
# 반복 : 907, 에러 : 0.00044960054583498277, 승리 : 689, 승리비율 : 75.88105726872246
# 반복 : 908, 에러 : 0.0005332311629899777, 승리 : 690, 승리비율 : 75.9075907590759
# 반복 : 909, 에러 : 0.0008640680098324083, 승리 : 691, 승리비율 : 75.93406593406593
# 반복 : 910, 에러 : 0.0006650713548879139, 승리 : 692, 승리비율 : 75.96048298572997
# 반복 : 911, 에러 : 0.0004836554198845988, 승리 : 693, 승리비율 : 75.98684210526315
# 반복 : 912, 에러 : 0.000572121876757592, 승리 : 694, 승리비율 : 76.013143483023
# 반복 : 913, 에러 : 0.000608632733928971, 승리 : 695, 승리비율 : 76.03938730853392
# 반복 : 914, 에러 : 0.000597521779127419, 승리 : 696, 승리비율 : 76.0655737704918
# 반복 : 915, 에러 : 0.0005505499066202901, 승리 : 697, 승리비율 : 76.09170305676855
# 반복 : 916, 에러 : 0.00050062254013028, 승리 : 698, 승리비율 : 76.11777535441658
# 반복 : 917, 에러 : 0.0006657343546976335, 승리 : 699, 승리비율 : 76.1437908496732
# 반복 : 918, 에러 : 0.00041211582356481813, 승리 : 700, 승리비율 : 76.16974972796517
# 반복 : 919, 에러 : 0.0005410514640971087, 승리 : 701, 승리비율 : 76.19565217391305
# 반복 : 920, 에러 : 0.00040688980698178057, 승리 : 702, 승리비율 : 76.2214983713355
# 반복 : 921, 에러 : 0.0003916498662874801, 승리 : 703, 승리비율 : 76.2472885032538
# 반복 : 922, 에러 : 0.0003230589663871797, 승리 : 704, 승리비율 : 76.273022751896
# 반복 : 923, 에러 : 0.00027882677841262193, 승리 : 705, 승리비율 : 76.2987012987013
# 반복 : 924, 에러 : 0.0003945367025153246, 승리 : 706, 승리비율 : 76.32432432432432
# 반복 : 925, 에러 : 0.00040506410914531443, 승리 : 707, 승리비율 : 76.3498920086393
# 반복 : 926, 에러 : 0.0003674963318189839, 승리 : 708, 승리비율 : 76.37540453074433
# 반복 : 927, 에러 : 0.00033947298834391404, 승리 : 709, 승리비율 : 76.40086206896551
# 반복 : 928, 에러 : 0.0003181520842190366, 승리 : 710, 승리비율 : 76.42626480086115
# 반복 : 929, 에러 : 0.00032549590650887694, 승리 : 711, 승리비율 : 76.45161290322581
# 반복 : 930, 에러 : 0.00038621789644821547, 승리 : 712, 승리비율 : 76.47690655209452
# 반복 : 931, 에러 : 0.0004083129606442526, 승리 : 713, 승리비율 : 76.50214592274678
# 반복 : 932, 에러 : 0.0005979096113151172, 승리 : 714, 승리비율 : 76.52733118971061
# 반복 : 933, 에러 : 0.00048564260578132235, 승리 : 715, 승리비율 : 76.55246252676659
# 반복 : 934, 에러 : 0.00037064534990349784, 승리 : 716, 승리비율 : 76.57754010695187
# 반복 : 935, 에러 : 0.00029051645105937496, 승리 : 717, 승리비율 : 76.6025641025641
# 반복 : 936, 에러 : 0.00031238542123901425, 승리 : 718, 승리비율 : 76.62753468516541
# 반복 : 937, 에러 : 0.00046906989518902265, 승리 : 719, 승리비율 : 76.65245202558634
# 반복 : 938, 에러 : 0.000255259481491521, 승리 : 720, 승리비율 : 76.6773162939297
# 반복 : 939, 에러 : 0.0003758864040719345, 승리 : 721, 승리비율 : 76.70212765957447
# 반복 : 940, 에러 : 0.00043375913446652703, 승리 : 722, 승리비율 : 76.7268862911796
# 반복 : 941, 에러 : 0.00028698185360553907, 승리 : 723, 승리비율 : 76.75159235668791
# 반복 : 942, 에러 : 0.00036410749180504354, 승리 : 724, 승리비율 : 76.7762460233298
# 반복 : 943, 에러 : 0.0003098036722803954, 승리 : 725, 승리비율 : 76.80084745762711
# 반복 : 944, 에러 : 0.00022602985518460628, 승리 : 726, 승리비율 : 76.82539682539684
# 반복 : 945, 에러 : 0.0002946105387309217, 승리 : 727, 승리비율 : 76.84989429175477
# 반복 : 946, 에러 : 0.0002680813195183873, 승리 : 728, 승리비율 : 76.87434002111932
# 반복 : 947, 에러 : 0.0004104308027308434, 승리 : 729, 승리비율 : 76.89873417721519
# 반복 : 948, 에러 : 0.0002518751434763544, 승리 : 730, 승리비율 : 76.92307692307693
# 반복 : 949, 에러 : 0.00040480064672010485, 승리 : 731, 승리비율 : 76.94736842105263
# 반복 : 950, 에러 : 0.0003608284341680701, 승리 : 732, 승리비율 : 76.97160883280758
# 반복 : 951, 에러 : 0.00030395103749469854, 승리 : 733, 승리비율 : 76.99579831932773
# 반복 : 952, 에러 : 0.0003227195447834674, 승리 : 734, 승리비율 : 77.01993704092341
# 반복 : 953, 에러 : 0.0003730946082214359, 승리 : 735, 승리비율 : 77.04402515723271
# 반복 : 954, 에러 : 0.00027094192410004325, 승리 : 736, 승리비율 : 77.06806282722512
# 반복 : 955, 에러 : 0.0003429598018556135, 승리 : 737, 승리비율 : 77.09205020920503
# 반복 : 956, 에러 : 0.0002667565731826471, 승리 : 738, 승리비율 : 77.11598746081505
# 반복 : 957, 에러 : 0.00033966290175158065, 승리 : 739, 승리비율 : 77.13987473903967
# 반복 : 958, 에러 : 0.00028900251709274016, 승리 : 740, 승리비율 : 77.16371220020855
# 반복 : 959, 에러 : 0.0002459806582919555, 승리 : 741, 승리비율 : 77.1875
# 반복 : 960, 에러 : 0.0002075646852972568, 승리 : 742, 승리비율 : 77.21123829344432
# 반복 : 961, 에러 : 0.0002743700097198598, 승리 : 743, 승리비율 : 77.23492723492723
# 반복 : 962, 에러 : 0.0002262899470224511, 승리 : 744, 승리비율 : 77.25856697819314
# 반복 : 963, 에러 : 0.0026537836783973034, 승리 : 745, 승리비율 : 77.28215767634855
# 반복 : 964, 에러 : 0.0002884116329369135, 승리 : 746, 승리비율 : 77.30569948186529
# 반복 : 965, 에러 : 0.00903117424059019, 승리 : 747, 승리비율 : 77.32919254658384
# 반복 : 966, 에러 : 0.0012100912717869505, 승리 : 748, 승리비율 : 77.35263702171665
# 반복 : 967, 에러 : 0.000423977522586938, 승리 : 749, 승리비율 : 77.37603305785123
# 반복 : 968, 에러 : 0.001567667226481717, 승리 : 750, 승리비율 : 77.39938080495357
# 반복 : 969, 에러 : 0.0003040710016648518, 승리 : 751, 승리비율 : 77.42268041237114
# 반복 : 970, 에러 : 0.001661981048528105, 승리 : 752, 승리비율 : 77.44593202883625
# 반복 : 971, 에러 : 0.0041742021348909475, 승리 : 753, 승리비율 : 77.46913580246914
# 반복 : 972, 에러 : 0.0023127860331442207, 승리 : 754, 승리비율 : 77.4922918807811
# 반복 : 973, 에러 : 0.001717076145723695, 승리 : 755, 승리비율 : 77.51540041067761
# 반복 : 974, 에러 : 0.0009990846738219261, 승리 : 756, 승리비율 : 77.53846153846153
# 반복 : 975, 에러 : 0.0013438348287309054, 승리 : 757, 승리비율 : 77.56147540983606
# 반복 : 976, 에러 : 0.0013485509407473728, 승리 : 758, 승리비율 : 77.58444216990789
# 반복 : 977, 에러 : 0.0016935709682002198, 승리 : 759, 승리비율 : 77.60736196319019
# 반복 : 978, 에러 : 0.00064859761914704, 승리 : 760, 승리비율 : 77.63023493360572
# 반복 : 979, 에러 : 0.0007689683625358157, 승리 : 761, 승리비율 : 77.65306122448979
# 반복 : 980, 에러 : 0.0006747832576365909, 승리 : 762, 승리비율 : 77.67584097859327
# 반복 : 981, 에러 : 0.00035677029245562153, 승리 : 763, 승리비율 : 77.69857433808554
# 반복 : 982, 에러 : 0.0003165022571920417, 승리 : 764, 승리비율 : 77.72126144455747
# 반복 : 983, 에러 : 0.000292323329631472, 승리 : 765, 승리비율 : 77.7439024390244
# 반복 : 984, 에러 : 0.00023660477017983794, 승리 : 766, 승리비율 : 77.76649746192894
# 반복 : 985, 에러 : 0.0002975897750729928, 승리 : 767, 승리비율 : 77.78904665314401
# 반복 : 986, 에러 : 0.00023111156224331353, 승리 : 768, 승리비율 : 77.81155015197568
# 반복 : 987, 에러 : 0.0005271140762488358, 승리 : 769, 승리비율 : 77.83400809716599
# 반복 : 988, 에러 : 0.001237394997588126, 승리 : 770, 승리비율 : 77.85642062689585
# 반복 : 989, 에러 : 0.0009768386116775218, 승리 : 771, 승리비율 : 77.87878787878788
# 반복 : 990, 에러 : 0.000244517475948669, 승리 : 772, 승리비율 : 77.90110998990917
# 반복 : 991, 에러 : 0.0006147459225758212, 승리 : 773, 승리비율 : 77.92338709677419
# 반복 : 992, 에러 : 0.00052134335237497, 승리 : 774, 승리비율 : 77.94561933534743
# 반복 : 993, 에러 : 0.00027663939908961765, 승리 : 775, 승리비율 : 77.96780684104627
# 반복 : 994, 에러 : 0.00017955646490008803, 승리 : 776, 승리비율 : 77.98994974874371
# 반복 : 995, 에러 : 0.0002882486460293876, 승리 : 777, 승리비율 : 78.01204819277109
# 반복 : 996, 에러 : 0.0002717387123993831, 승리 : 778, 승리비율 : 78.03410230692076
# 반복 : 997, 에러 : 0.0010762041001726175, 승리 : 779, 승리비율 : 78.0561122244489
# 반복 : 998, 에러 : 0.0008310241701110499, 승리 : 780, 승리비율 : 78.07807807807808
# 반복 : 999, 에러 : 0.00047157821063592564, 승리 : 781, 승리비율 : 78.10000000000001
# 반복 : 1000, 에러 : 0.0005510213231900707, 승리 : 782, 승리비율 : 78.12187812187813
# 학습이 완료되었습니다.
# 모델을 저장하였습니다.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
